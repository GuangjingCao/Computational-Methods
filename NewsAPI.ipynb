# %% [markdown]
# # Example 1. Authorizing an application to access NewsAPI data

# %%
# !pip install newsapi-python
# Out:
# Requirement already satisfied: newsapi-python in /home/jw2204/miniconda3/envs/GC/lib/python3.11/site-packages (0.2.7)
# Requirement already satisfied: requests<3.0.0 in /home/jw2204/miniconda3/envs/GC/lib/python3.11/site-packages (from newsapi-python) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jw2204/miniconda3/envs/GC/lib/python3.11/site-packages (from requests<3.0.0->newsapi-python) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/jw2204/miniconda3/envs/GC/lib/python3.11/site-packages (from requests<3.0.0->newsapi-python) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jw2204/miniconda3/envs/GC/lib/python3.11/site-packages (from requests<3.0.0->newsapi-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jw2204/miniconda3/envs/GC/lib/python3.11/site-packages (from requests<3.0.0->newsapi-python) (2025.10.5)

# %%
from newsapi import NewsApiClient

# See https://newsapi.org/docs for more information
# on NewsAPI implementation.

API_KEY = '4199f4bb632f47cca033ed58a2532974'

newsapi = NewsApiClient(api_key=API_KEY)
print(newsapi)
# Out:
# <newsapi.newsapi_client.NewsApiClient object at 0x7625c19f5ed0>

# %% [markdown]
# # Back to slides

# %% [markdown]
# # Example 2.  All possible sources and retrieving top headlines

# %%
sources = newsapi.get_sources()

# %%
print(sources)
# Out:
# {'status': 'ok', 'sources': [{'id': 'abc-news', 'name': 'ABC News', 'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.', 'url': 'https://abcnews.go.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'abc-news-au', 'name': 'ABC News (AU)', 'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.", 'url': 'https://www.abc.net.au/news', 'category': 'general', 'language': 'en', 'country': 'au'}, {'id': 'aftenposten', 'name': 'Aftenposten', 'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.', 'url': 'https://www.aftenposten.no', 'category': 'general', 'language': 'no', 'country': 'no'}, {'id': 'al-jazeera-english', 'name': 'Al Jazeera English', 'description': 'News, analysis from the Middle East and worldwide, multimedia and interactives, opinions, documentaries, podcasts, long reads and broadcast schedule.', 'url': 'https://www.aljazeera.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'ansa', 'name': 'ANSA.it', 'description': 'Agenzia ANSA: ultime notizie, foto, video e approfondimenti su: cronaca, politica, economia, regioni, mondo, sport, calcio, cultura e tecnologia.', 'url': 'https://www.ansa.it', 'category': 'general', 'language': 'it', 'country': 'it'}, {'id': 'argaam', 'name': 'Argaam', 'description': 'ارقام موقع متخصص في متابعة سوق الأسهم السعودي تداول - تاسي - مع تغطيه معمقة لشركات واسعار ومنتجات البتروكيماويات , تقارير مالية الاكتتابات الجديده ', 'url': 'https://www.argaam.com', 'category': 'business', 'language': 'ar', 'country': 'sa'}, {'id': 'ars-technica', 'name': 'Ars Technica', 'description': "The PC enthusiast's resource. Power users and the tools they love, without computing religion.", 'url': 'https://arstechnica.com', 'category': 'technology', 'language': 'en', 'country': 'us'}, {'id': 'ary-news', 'name': 'Ary News', 'description': 'ARY News is a Pakistani news channel committed to bring you up-to-the minute Pakistan news and featured stories from around Pakistan and all over the world.', 'url': 'https://arynews.tv/ud/', 'category': 'general', 'language': 'ud', 'country': 'pk'}, {'id': 'associated-press', 'name': 'Associated Press', 'description': 'The AP delivers in-depth coverage on the international, politics, lifestyle, business, and entertainment news.', 'url': 'https://apnews.com/', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'australian-financial-review', 'name': 'Australian Financial Review', 'description': 'The Australian Financial Review reports the latest news from business, finance, investment and politics, updated in real time. It has a reputation for independent, award-winning journalism and is essential reading for the business and investor community.', 'url': 'http://www.afr.com', 'category': 'business', 'language': 'en', 'country': 'au'}, {'id': 'axios', 'name': 'Axios', 'description': 'Axios are a new media company delivering vital, trustworthy news and analysis in the most efficient, illuminating and shareable ways possible.', 'url': 'https://www.axios.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'bbc-news', 'name': 'BBC News', 'description': 'Use BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news.', 'url': 'https://www.bbc.co.uk/news', 'category': 'general', 'language': 'en', 'country': 'gb'}, {'id': 'bbc-sport', 'name': 'BBC Sport', 'description': 'The home of BBC Sport online. Includes live sports coverage, breaking news, results, video, audio and analysis on Football, F1, Cricket, Rugby Union, Rugby League, Golf, Tennis and all the main world sports, plus ma ...

# %%
top_headlines = newsapi.get_top_headlines(#q='bitcoin',
                                          #sources='bbc-news,the-verge',
                                          #category='business',
                                          language='en',
                                          country='us'
                                          )

# %%
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 34, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': "David L. Stern, Siobhán O'Grady, Anastacia Galouchka", 'title': 'Ukraine must choose between saving territory or its men in Pokrovsk fight - The Washington Post', 'description': 'Pokrovsk has been a bastion of resistance, and Russia taking it would be a propaganda win, but experts say it is time to withdraw and save lives for future battles.', 'url': 'https://www.washingtonpost.com/world/2025/11/06/ukraine-pokrovsk-fall-russia-war/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/5H6UHJPD2BMHPWJUU2EACVBTWA.JPG&w=1440', 'publishedAt': '2025-11-06T12:32:03Z', 'content': 'Pokrovsk has been a bastion of resistance, and Russia taking it would be a propaganda win, but experts say it is time to withdraw and save lives for future battles.\r\nNovember 6, 2025 at 3:00 a.m. EST… [+21 chars]'}, {'source': {'id': None, 'name': 'CNBC'}, 'author': 'Jeff Cox', 'title': 'Job cuts in October hit highest level for the month in 22 years, Challenger says - CNBC', 'description': 'Job cuts for October totaled 153,074, a 183% surge from September.', 'url': 'https://www.cnbc.com/2025/11/06/job-cuts-in-october-hit-highest-level-for-the-month-in-22-years-challenger-says.html', 'urlToImage': 'https://image.cnbcfm.com/api/v1/image/108203774-1758802270042-gettyimages-2231677197-US_JOBS.jpeg?v=1758802638&w=1920&h=1080', 'publishedAt': '2025-11-06T12:23:33Z', 'content': 'Layoff announcements soared in October as companies recalibrated staffing levels during the artificial intelligence boom, a sign of potential trouble ahead for the labor market, according to outplace… [+2425 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Faiz Siddiqui', 'title': 'The contentious fight over Elon Musk’s $1 trillion pay package - The Washington Post', 'description': 'A proposed pay package could make Tesla CEO Elon Musk the world’s first trillionaire, but it faces resistance from shareholders and critics who say it’s unearned.', 'url': 'https://www.washingtonpost.com/technology/2025/11/06/elon-musk-tesla-pay-package/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/E3SO7HA4J7TAU5WARYLQKTLH6A.jpg&w=1440', 'publishedAt': '2025-11-06T11:30:55Z', 'content': 'Tesla and its shareholders have mounted an unusual offensive in recent days to win backing for a $1 trillion CEO pay package, arguing the unprecedented payday is necessary to keep Elon Musk at the he… [+72 chars]'}, {'source': {'id': 'associated-press', 'name': 'Associated Press'}, 'author': 'Chalida Ekvitthayavechnukul, David Rising', 'title': 'An American man and his son die after suffering stings from a swarm of wasps while ziplining in Laos - AP News', 'description': 'An American man and his teenage son have died after they were stung by a swarm of wasps while ziplining in Laos last month. The incident occurred last month near the city of Luang Prabang, a popular tourist site in the Southeast Asian nation that was named a …', 'url': 'https://apnews.com/article/wasp-hornet-attack-laos-americans-killed-891a004e2945b065af14d2340d2d3e8c', 'urlToImage': 'https://dims.apnews.com/dims4/default/6415b10/2147483647/strip/true/crop/6000x3375+0+312/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F8e%2F6b%2F9445cafcfbfe0d144b7eab4c4601%2F4d4e6d5105c7478dba0bf145a209cb65', 'publishedAt': '2025-11-06T11:22:00Z', 'content': 'BANGKOK (AP) An American man and his teenage son died last month after they were swarmed by wasps while ziplining at an adventure camp in Laos and stung many dozens of times, a hospital official said… [+2214 chars]'}, {'source': {'id': None, 'name': 'BBC News'}, 'author': 'https://www.facebook.com/bbcnews', 'title': 'Interest rates expected to sta ...

# %% [markdown]
# # Saving data!
#
# Very important!
#
# ![important](https://media.istockphoto.com/photos/important-picture-id186613912?k=6&m=186613912&s=612x612&w=0&h=bMibIfwwjrEW93VWjr3f-wCJwrNn5nyX4TqfitGxwAk=)

# %%
# store data locally (if you run this code locally) 
# or store it temporary in the virtual machine (if you run this code in a cloud service such as google colab)
import json
data= json.dumps(top_headlines, indent=1)

file = open('foo.txt','w')
file.write(data)
file.close()

# %%
file = open('foo.txt','r')
foo = file.read()
d = json.loads(foo)

print(len(d['articles']))
for article in d['articles']:
  print(f"author: {article['author']}")
  print(f"title: {article['title']}")
  print(f"description: {article['description']}")
# Out:
# 18
# author: David L. Stern, Siobhán O'Grady, Anastacia Galouchka
# title: Ukraine must choose between saving territory or its men in Pokrovsk fight - The Washington Post
# description: Pokrovsk has been a bastion of resistance, and Russia taking it would be a propaganda win, but experts say it is time to withdraw and save lives for future battles.
# author: Jeff Cox
# title: Job cuts in October hit highest level for the month in 22 years, Challenger says - CNBC
# description: Job cuts for October totaled 153,074, a 183% surge from September.
# author: Faiz Siddiqui
# title: The contentious fight over Elon Musk’s $1 trillion pay package - The Washington Post
# description: A proposed pay package could make Tesla CEO Elon Musk the world’s first trillionaire, but it faces resistance from shareholders and critics who say it’s unearned.
# author: Chalida Ekvitthayavechnukul, David Rising
# title: An American man and his son die after suffering stings from a swarm of wasps while ziplining in Laos - AP News
# description: An American man and his teenage son have died after they were stung by a swarm of wasps while ziplining in Laos last month. The incident occurred last month near the city of Luang Prabang, a popular tourist site in the Southeast Asian nation that was named a …
# author: https://www.facebook.com/bbcnews
# title: Interest rates expected to stay at 4% as Bank of England makes pre-Budget decision - BBC
# description: It's the final decision on the base rate before Chancellor Rachel Reeves delivers her Budget later this month.
# author: Will Stone
# title: Bird flu surges among poultry amid a scaled back federal response : Shots - Health News - NPR
# description: Migrating wild birds are spreading the virus to domesticated flocks, increasing the risk of eventually seeing a human outbreak. Scientists are troubled by the muted federal response.
# author:
# title: How would the government shutdown affect Thanksgiving travel? Here's what to know - NPR
# description: Holiday travel can already be stressful. Here's how a prolonged government shutdown might make things even harder and whether you should travel at all.
# author: Yeo Boon Ping
# title: CNBC Daily Open: The Supreme Court might not have the last word on Trump tariffs - CNBC
# description: The end of tariffs wouldn't be an unequivocal win for stocks. It could cause yields to rise — and Trump might try to reinstate tariffs through other means.
# author: None
# title: Horoscope for Thursday, November 06, 2025 - Chicago Sun-Times
# description: None
# author: None
# title: Golden State Warriors vs. Sacramento Kings Live Score and Stats - November 5, 2025 Gametracker - CBS Sports
# description: Get real-time NBA Basketball coverage and scores as Golden State Warriors takes on Sacramento Kings. We bring you the latest game previews, live stats, expert picks and recaps on CBSSports.com
# author: Associated Press
# title: Mississippi Democrats appear to break Republican supermajority in state Senate - Politico
# description: Democrats generally fared well in statehouse elections Tuesday.
# author: None
# title: Alex Ovechkin scores his 900th NHL goal with the Washington Capitals - AP News
# description: The NHL now has a 900-goal club. Charter member: Alex Ovechkin, of course. The Washington star pushed his record total to a new level Wednesday night, scoring against the St. Louis Blues to reach 900. The milestone came 2:39 into the second period. Ovechkin w…
# author: None
# title: How caffeine can help you manage headaches and three other tips - BBC
# description: If you're getting a pattern of milder, recurring headaches here are four things you can do to help manage it.
# author: Nicole  Sganga
# title: ICE officer seriously injured by detainee as threats against agents rise, Homeland Security says - CBS News
# description: DHS said an ICE officer was seriously injured Monday after being struck in the face with a metal coffee cup during an arrest operation in Houston.
# author: Tom  Hanson
# title: Workers at Louisville business near UPS plane crash recall "explosion after explosion," melted clothes and chaos - CBS News
# description: At least 12 people were killed and several others injured after a UPS plane crashed shortly after taking off from the Louisville International Airport on Tuesday.
# author: The Associated Press
# title: Bigger, brighter, closer: November’s supermoon in photos - AP News
# description: This is a photo gallery curated by AP photo editors.
# author: Kevin Liptak
# title: Trump wants GOP to focus more on his economic achievements. But he’s often changing the subject. - CNN
# description: President Donald Trump spent the morning after a terrible election night for Republicans publicly processing the results, and arrived at several conclusions.
# author: Robert Lea
# title: The expansion of our universe may be slowing down. What does that mean for dark energy? - Space
# description: The expansion of our universe may be slowing down. What does that mean for dark energy?

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 3. Displaying API responses as pretty-printed JSON

# %%
import json
print(json.dumps(top_headlines, indent=1))
# Out:
# {
#  "status": "ok",
#  "totalResults": 34,
#  "articles": [
#   {
#    "source": {
#     "id": "the-washington-post",
#     "name": "The Washington Post"
#    },
#    "author": "David L. Stern, Siobh\u00e1n O'Grady, Anastacia Galouchka",
#    "title": "Ukraine must choose between saving territory or its men in Pokrovsk fight - The Washington Post",
#    "description": "Pokrovsk has been a bastion of resistance, and Russia taking it would be a propaganda win, but experts say it is time to withdraw and save lives for future battles.",
#    "url": "https://www.washingtonpost.com/world/2025/11/06/ukraine-pokrovsk-fall-russia-war/",
#    "urlToImage": "https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/5H6UHJPD2BMHPWJUU2EACVBTWA.JPG&w=1440",
#    "publishedAt": "2025-11-06T12:32:03Z",
#    "content": "Pokrovsk has been a bastion of resistance, and Russia taking it would be a propaganda win, but experts say it is time to withdraw and save lives for future battles.\r\nNovember 6, 2025 at 3:00 a.m. EST\u2026 [+21 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "CNBC"
#    },
#    "author": "Jeff Cox",
#    "title": "Job cuts in October hit highest level for the month in 22 years, Challenger says - CNBC",
#    "description": "Job cuts for October totaled 153,074, a 183% surge from September.",
#    "url": "https://www.cnbc.com/2025/11/06/job-cuts-in-october-hit-highest-level-for-the-month-in-22-years-challenger-says.html",
#    "urlToImage": "https://image.cnbcfm.com/api/v1/image/108203774-1758802270042-gettyimages-2231677197-US_JOBS.jpeg?v=1758802638&w=1920&h=1080",
#    "publishedAt": "2025-11-06T12:23:33Z",
#    "content": "Layoff announcements soared in October as companies recalibrated staffing levels during the artificial intelligence boom, a sign of potential trouble ahead for the labor market, according to outplace\u2026 [+2425 chars]"
#   },
#   {
#    "source": {
#     "id": "the-washington-post",
#     "name": "The Washington Post"
#    },
#    "author": "Faiz Siddiqui",
#    "title": "The contentious fight over Elon Musk\u2019s $1 trillion pay package - The Washington Post",
#    "description": "A proposed pay package could make Tesla CEO Elon Musk the world\u2019s first trillionaire, but it faces resistance from shareholders and critics who say it\u2019s unearned.",
#    "url": "https://www.washingtonpost.com/technology/2025/11/06/elon-musk-tesla-pay-package/",
#    "urlToImage": "https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/E3SO7HA4J7TAU5WARYLQKTLH6A.jpg&w=1440",
#    "publishedAt": "2025-11-06T11:30:55Z",
#    "content": "Tesla and its shareholders have mounted an unusual offensive in recent days to win backing for a $1 trillion CEO pay package, arguing the unprecedented payday is necessary to keep Elon Musk at the he\u2026 [+72 chars]"
#   },
#   {
#    "source": {
#     "id": "associated-press",
#     "name": "Associated Press"
#    },
#    "author": "Chalida Ekvitthayavechnukul, David Rising",
#    "title": "An American man and his son die after suffering stings from a swarm of wasps while ziplining in Laos - AP News",
#    "description": "An American man and his teenage son have died after they were stung by a swarm of wasps while ziplining in Laos last month. The incident occurred last month near the city of Luang Prabang, a popular tourist site in the Southeast Asian nation that was named a \u2026",
#    "url": "https://apnews.com/article/wasp-hornet-attack-laos-americans-killed-891a004e2945b065af14d2340d2d3e8c",
#    "urlToImage": "https://dims.apnews.com/dims4/default/6415b10/2147483647/strip/true/crop/6000x3375+0+312/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F8e%2F6b%2F9445cafcfbfe0d144b7eab4c4601%2F4d4e6d5105c7478dba0bf145a209cb65",
#    "publishedAt": "2025-11-06T11:22:00Z",
#    "content": "BANGKOK (AP) An American man and his teenage son died last month after they were swarmed by wasps while ziplining at an adventure camp in Laos and stung many dozens of times, a hospital official said\u2026 [+2214 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "BBC News"
#    },
#    "author": "https://www.facebook.com/bbcnews",
#    "title": "Interest rates expected to stay at 4% as Bank of England makes pre-Budget decision - BBC",
#    "description": "It's the final decision on the base rate before Chancellor Rachel Reeves delivers her Budget later this month.",
#    "url": "https://www.bbc.com/news/live/c5yd94g13e9t",
#    "urlToImage": "https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/1d52/live/ffddbb60-b298-11f0-8d8b-0d4dded1af00.jpg",
#    "publishedAt": "2025-11-06T11:09:44Z",
#    "content": "Michael RaceBusiness and economics reporter, at the Bank of England\r\nDepending on your individual circumstances, interest rates can impact you in different ways.\r\nMortgage holders with variable or tr\u2026 [+1100 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NPR"
#    },
#    "author": "Will Stone",
#    "title": "Bird flu surges among poultry amid a scaled back federal response : Shots - Health News - NPR",
#    "description": "Migrating wild birds are spreading the virus to domesticated flocks, increasing the risk of eventually seeing a human outbreak. Scientists are troubled by the muted federal response.",
#    "url": "https://www.npr.org/sections/shots-health-news/2025/11/06/nx-s1-5600125/bird-flu-risk-outbreak-trump-administration",
#    "urlToImage": "https://npr.brightspotcdn.com/dims3/default/strip/false/crop/1024x576+0+54/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F95%2F9d%2F1450a56e446ca17bab6a2fb18e95%2Fgettyimages-1246952878.jpg",
#    "publishedAt": "2025-11-06T11:00:00Z",
#    "content": "As birds fly south for the winter, they're carrying with them some unwelcome cargo: the H5N1 virus, or bird flu.\r\nIn the past 30 days, the virus has struck 66 poultry flocks, leading to the deaths of\u2026 [+6963 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NPR"
#    },
#    "author": "",
#    "title": "How would the government shutdown affect Thanksgiving travel? Here's what to know - NPR",
#    "description": "Holiday travel can already be stressful. Here's how a prolonged government shutdown might make things even harder and whether you should travel at all.",
#    "url": "https://www.npr.org/2025/11/06/nx-s1-5599582/government-shutdown-airport-thanksgiving-travel",
#    "urlToImage": "https://npr.brightspotcdn.com/dims3/default/strip/false/crop/2518x1416+0+313/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Feb%2F10%2F38588113403d829c89305204dfbd%2Fgettyimages-1230028671.jpg",
#    "publishedAt": "2025-11-06T10:00:00Z",
#    "content": "With wintry weather and crowded airports, Thanksgiving travel can already be stressful. Now, add into the mix the possibility that the government shutdown could extend until then.\r\nTens of thousands \u2026 [+4735 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "CNBC"
#    },
#    "author": "Yeo Boon Ping",
#    "title": "CNBC Daily Open: The Supreme Court might not have the last word on Trump tariffs - CNBC",
#    "description": "The end of tariffs wouldn't be an unequivocal win for stocks. It could cause yields to rise \u2014 and Trump might try to reinstate tariffs through other means.",
#    "url": "https://www.cnbc.com/2025/11/06/cnbc-daily-open-supreme-court-might-not-have-last-word-on-trump-tariffs.html",
#    "urlToImage": "https://image.cnbcfm.com/api/v1/image/108208210-17597642142025-10-06t142006z_106926239_rc2e6ha6jm2p_rtrmadp_0_usa-court.jpeg?v=1759764259&w=1920&h=1080",
#    "publishedAt": "2025-11-06T07:30:01Z",
#    "content": "The U.S. Supreme Court on Wednesday heard a case on the Trump administration's \"reciprocal\" tariffs, and both liberal and conservative judges appeared skeptical of the legal basis of those tariffs.\r\n\u2026 [+1119 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Suntimes.com"
#    },
#    "author": null,
#    "title": "Horoscope for Thursday, November 06, 2025 - Chicago Sun-Times",
#    "description": null,
#    "url": "https://chicago.suntimes.com/horoscopes/2025/11/06/horoscopes-today-thursday-november-06-2025",
#    "urlToImage": "https://cst.brightspotcdn.com/dims4/default/2145dbd/2147483647/strip/true/crop/870x497+0+67/resize/1461x834!/quality/90/?url=https%3A%2F%2Fchorus-production-cst-web.s3.us-east-1.amazonaws.com%2Fbrightspot%2Fac%2Ffd%2F790f04b15195427014757adc0272%2Fgeorgia-nicols.jpg",
#    "publishedAt": "2025-11-06T06:01:00Z",
#    "content": "Moon Alert\r\nAvoid shopping (except food and gas) or important decisions from 8:15 a.m. to 9:30 a.m. After that, the moon moves from Taurus into Gemini.\r\nAries (March 21-April 19)\r\n Keep your eyes ope\u2026 [+3864 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "CBS Sports"
#    },
#    "author": null,
#    "title": "Golden State Warriors vs. Sacramento Kings Live Score and Stats - November 5, 2025 Gametracker - CBS Sports",
#    "description": "Get real-time NBA Basketball coverage and scores as Golden State Warriors takes on Sacramento Kings. We bring you the latest game previews, live stats, expert picks and recaps on CBSSports.com",
#    "url": "https://www.cbssports.com/nba/gametracker/recap/NBA_20251105_GS@SAC/",
#    "urlToImage": "https://sportsfly.cbsistatic.com/fly-324/bundles/sportsmediacss/images/fantasy/default-article-image-large.png",
#    "publishedAt": "2025-11-06T05:42:28Z",
#    "content": "SACRAMENTO, Calif. (AP) Russell Westbrook posted his NBA-record 204th career triple-double and Dennis Schroder sparked a key fourth-quarter spurt that gave the Sacramento Kings a 121-116 win over the\u2026 [+1817 chars]"
#   },
#   {
#    "source": {
#     "id": "politico",
#     "name": "Politico"
#    },
#    "author": "Associated Press",
#    "title": "Mississippi Democrats appear to break Republican supermajority in state Senate - Politico",
#    "description": "Democrats generally fared well in statehouse elections Tuesday.",
#    "url": "https://www.politico.com/news/2025/11/06/mississippi-democrats-appear-to-break-republican-supermajority-in-state-senate-00639455",
#    "urlToImage": "https://www.politico.com/dims4/default/resize/1200/quality/90/format/jpg?url=https%3A%2F%2Fstatic.politico.com%2F64%2F9c%2F19168c254510b7513a2f3af4b360%2Felection-2025-mississippi-legislature-50128.jpg",
#    "publishedAt": "2025-11-06T05:34:49Z",
#    "content": "The victories would mean Republicans no longer have a two-thirds majority in the Mississippi Senate when the new lawmakers take office.\r\nMississippi voters reminded us that change is possible when we\u2026 [+2245 chars]"
#   },
#   {
#    "source": {
#     "id": "associated-press",
#     "name": "Associated Press"
#    },
#    "author": null,
#    "title": "Alex Ovechkin scores his 900th NHL goal with the Washington Capitals - AP News",
#    "description": "The NHL now has a 900-goal club. Charter member: Alex Ovechkin, of course. The Washington star pushed his record total to a new level Wednesday night, scoring against the St. Louis Blues to reach 900. The milestone came 2:39 into the second period. Ovechkin w\u2026",
#    "url": "https://apnews.com/article/alex-ovechkin-washington-capitals-900th-goal-3723f79174bd7ec9f979d9fee13c7662",
#    "urlToImage": "https://dims.apnews.com/dims4/default/22cb981/2147483647/strip/true/crop/8481x4771+0+441/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2Fc7%2F1d%2Fd09b1632c4326bbc027d5f8358c1%2F3197e9a1c7834efdaa410ba5bad22716",
#    "publishedAt": "2025-11-06T04:01:00Z",
#    "content": "WASHINGTON (AP) The NHL now has a 900-goal club.\r\nCharter member: Alex Ovechkin, of course.\r\nThe Washington star pushed his record total to a new level Wednesday night, scoring against Jordan Binning\u2026 [+2730 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "BBC News"
#    },
#    "author": null,
#    "title": "How caffeine can help you manage headaches and three other tips - BBC",
#    "description": "If you're getting a pattern of milder, recurring headaches here are four things you can do to help manage it.",
#    "url": "https://www.bbc.com/news/articles/cgr44j201rzo",
#    "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/8c33/live/26185cc0-b8a9-11f0-9418-d155a3381a50.jpg",
#    "publishedAt": "2025-11-06T02:45:03Z",
#    "content": "Headaches are something almost all of us deal with at some point.\r\nThey can last from a couple of minutes to days and the pain can be sharp, dull, throbbing or stabbing and sometimes spread beyond yo\u2026 [+4241 chars]"
#   },
#   {
#    "source": {
#     "id": "cbs-news",
#     "name": "CBS News"
#    },
#    "author": "Nicole  Sganga",
#    "title": "ICE officer seriously injured by detainee as threats against agents rise, Homeland Security says - CBS News",
#    "description": "DHS said an ICE officer was seriously injured Monday after being struck in the face with a metal coffee cup during an arrest operation in Houston.",
#    "url": "https://www.cbsnews.com/news/ice-officer-seriously-injured-detainee-threats-agents-homeland-security/",
#    "urlToImage": "https://assets2.cbsnewsstatic.com/hub/i/r/2025/10/03/12b92bb0-a0dc-49a8-a88d-0c1a3d99eb38/thumbnail/1200x630/e692e08380bc32fbbc775cdcfaac1ce5/gettyimages-2235809851.jpg",
#    "publishedAt": "2025-11-06T02:36:00Z",
#    "content": "Washington \u2014 A U.S. Immigration and Customs Enforcement officer was seriously injured Monday after being struck in the face with a metal coffee cup during an arrest operation in Houston, according to\u2026 [+4943 chars]"
#   },
#   {
#    "source": {
#     "id": "cbs-news",
#     "name": "CBS News"
#    },
#    "author": "Tom  Hanson",
#    "title": "Workers at Louisville business near UPS plane crash recall \"explosion after explosion,\" melted clothes and chaos - CBS News",
#    "description": "At least 12 people were killed and several others injured after a UPS plane crashed shortly after taking off from the Louisville International Airport on Tuesday.",
#    "url": "https://www.cbsnews.com/news/ups-plane-crash-louisville-witnesses-react/",
#    "urlToImage": "https://assets1.cbsnewsstatic.com/hub/i/r/2025/11/05/4d4e198a-4a42-48bd-9055-e516748ec6bf/thumbnail/1200x630/781def44534738bb33de6052b720127a/screenshot-2025-11-05-at-5-56-31-pm.png",
#    "publishedAt": "2025-11-06T01:15:00Z",
#    "content": "When Georgie Dow heard an explosion at the auto parts recycling business where she works in Louisville, Kentucky, she had no idea\u00a0a UPS aircraft had just crashed outside.\u00a0\r\nDow, the chief financial o\u2026 [+3639 chars]"
#   },
#   {
#    "source": {
#     "id": "associated-press",
#     "name": "Associated Press"
#    },
#    "author": "The Associated Press",
#    "title": "Bigger, brighter, closer: November\u2019s supermoon in photos - AP News",
#    "description": "This is a photo gallery curated by AP photo editors.",
#    "url": "https://apnews.com/photo-gallery/november-supermoon-2025-7f9861cb18b207cd9f5fefcb124f2ae4",
#    "urlToImage": "https://dims.apnews.com/dims4/default/66fbee9/2147483647/strip/true/crop/5894x3315+0+307/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F28%2F55%2F310a5b1f59388298309caeabf32f%2F62fc2efae67643a3bdfe4eb4383d631b",
#    "publishedAt": "2025-11-06T01:03:00Z",
#    "content": "The supermoon rises behind the illuminated Golden Temple as Sikh devotees pray at the to mark the birth anniversary of their first guru, Guru Nanak, in Amritsar, India, Wednesday, Nov. 5, 2025. (AP P\u2026 [+18 chars]"
#   },
#   {
#    "source": {
#     "id": "cnn",
#     "name": "CNN"
#    },
#    "author": "Kevin Liptak",
#    "title": "Trump wants GOP to focus more on his economic achievements. But he\u2019s often changing the subject. - CNN",
#    "description": "President Donald Trump spent the morning after a terrible election night for Republicans publicly processing the results, and arrived at several conclusions.",
#    "url": "https://www.cnn.com/2025/11/05/politics/trump-republicans-messaging-2025-elections",
#    "urlToImage": "https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2245190487.jpg?c=16x9&q=w_800,c_fill",
#    "publishedAt": "2025-11-06T00:19:00Z",
#    "content": "President Donald Trump spent the morning after a terrible election night for Republicans publicly processing the results, and arrived at several conclusions.\r\nFirst, he determined his party was losin\u2026 [+6774 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Space.com"
#    },
#    "author": "Robert Lea",
#    "title": "The expansion of our universe may be slowing down. What does that mean for dark energy? - Space",
#    "description": "The expansion of our universe may be slowing down. What does that mean for dark energy?",
#    "url": "https://www.space.com/astronomy/dark-universe/the-expansion-of-our-universe-may-be-slowing-down-what-does-that-mean-for-dark-energy",
#    "urlToImage": "https://cdn.mos.cms.futurecdn.net/wUx53AGN62CRwCSWxRfwpS-1600-80.png",
#    "publishedAt": "2025-11-06T00:02:56Z",
#    "content": "As if dark energy weren't already mysterious and baffling enough, new research suggests that this unknown force may not be driving galaxies apart at an accelerating rate anymore.\r\nThis remarkable res\u2026 [+5607 chars]"
#   }
#  ]
# }

# %%
for i in range(5):
    print(top_headlines['articles'][i]['url'])
# Out:
# https://www.washingtonpost.com/world/2025/11/06/ukraine-pokrovsk-fall-russia-war/
# https://www.cnbc.com/2025/11/06/job-cuts-in-october-hit-highest-level-for-the-month-in-22-years-challenger-says.html
# https://www.washingtonpost.com/technology/2025/11/06/elon-musk-tesla-pay-package/
# https://apnews.com/article/wasp-hornet-attack-laos-americans-killed-891a004e2945b065af14d2340d2d3e8c
# https://www.bbc.com/news/live/c5yd94g13e9t

# %%
from IPython.display import Image
from IPython.core.display import HTML

for i in range(5):
  print(top_headlines['articles'][i]['title'])
  try:
    image = Image(url=top_headlines['articles'][i]['urlToImage'])
    display(image)
  except ValueError:
    print('no image')
# Out:
# Ukraine must choose between saving territory or its men in Pokrovsk fight - The Washington Post
# <img src="https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/5H6UHJPD2BMHPWJUU2EACVBTWA.JPG&w=1440"/>
# Job cuts in October hit highest level for the month in 22 years, Challenger says - CNBC
# <img src="https://image.cnbcfm.com/api/v1/image/108203774-1758802270042-gettyimages-2231677197-US_JOBS.jpeg?v=1758802638&w=1920&h=1080"/>
# The contentious fight over Elon Musk’s $1 trillion pay package - The Washington Post
# <img src="https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/E3SO7HA4J7TAU5WARYLQKTLH6A.jpg&w=1440"/>
# An American man and his son die after suffering stings from a swarm of wasps while ziplining in Laos - AP News
# <img src="https://dims.apnews.com/dims4/default/6415b10/2147483647/strip/true/crop/6000x3375+0+312/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F8e%2F6b%2F9445cafcfbfe0d144b7eab4c4601%2F4d4e6d5105c7478dba0bf145a209cb65"/>
# Interest rates expected to stay at 4% as Bank of England makes pre-Budget decision - BBC
# <img src="https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/1d52/live/ffddbb60-b298-11f0-8d8b-0d4dded1af00.jpg"/>

# %% [markdown]
# # Example 4. Collecting search results

# %%
#  Set this variable to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

#q = 'ai'
#q = 'data science'
#q = 'toyota'
q = 'baseball'

all_articles = newsapi.get_everything(q=q,
                                      #sources='bbc-news,the-verge',
                                      #domains='bbc.co.uk,techcrunch.com',
                                      from_param='2025-09-24',
                                      to='2025-10-08',
                                      language='en',
                                      sort_by='relevancy',
                                      #page=2
                                      )

# Show one sample search result by slicing the list...
print(json.dumps(all_articles, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# Cell In[12], line 11
#       1 #  Set this variable to a trending topic,
#       2 # or anything else for that matter. The example query below
#       3 # was a trending topic when this content was being developed
#    (...)      7 #q = 'data science'
#       8 #q = 'toyota'
#       9 q = 'baseball'
# ---> 11 all_articles = newsapi.get_everything(q=q,
#      12                                       #sources='bbc-news,the-verge',
#      13                                       #domains='bbc.co.uk,techcrunch.com',
#      14                                       from_param='2025-09-24',
#      15                                       to='2025-10-08',
#      16                                       language='en',
#      17                                       sort_by='relevancy',
#      18                                       #page=2
#      19                                       )
#      21 # Show one sample search result by slicing the list...
#      22 print(json.dumps(all_articles, indent=4))
#
# File ~/miniconda3/envs/GC/lib/python3.11/site-packages/newsapi/newsapi_client.py:334, in NewsApiClient.get_everything(self, q, qintitle, sources, domains, exclude_domains, from_param, to, language, sort_by, page, page_size)
#     332 # Check Status of Request
#     333 if r.status_code != requests.codes.ok:
# --> 334     raise NewsAPIException(r.json())
#     336 return r.json()
#
# NewsAPIException: {'status': 'error', 'code': 'parameterInvalid', 'message': 'You are trying to request results too far in the past. Your plan permits you to request articles as far back as 2025-10-06, but you have requested 2025-09-24. You may need to upgrade to a paid plan.'}

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 5. Extracting authors, sources, and descriptions from articles

# %%
import time

authors = [ article['author'] for article in all_articles['articles'] ]

sources = [ article['source']['name'] for article in all_articles['articles'] ]

descriptions = [ article['description'] for article in all_articles['articles'] ]

print(type(descriptions))
# Compute a collection of all words from all tweets
words = [
    w
    for d in descriptions
    if d is not None          # skip None values
    for w in d.split()
]

# Explore the first 5 items for each...

print(json.dumps(authors[0:5], indent=1))
print(json.dumps(sources[0:5], indent=1))
print(json.dumps(descriptions[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# <class 'list'>
# [
#  "Mike Sorrentino",
#  "Eric Karabell",
#  "David Schoenfield",
#  "Becky Sullivan",
#  "Joe Rossignol"
# ]
# [
#  "CNET",
#  "ESPN",
#  "ESPN",
#  "NPR",
#  "MacRumors"
# ]
# [
#  "Apple's new Pro phone will be used to film the Detroit Tigers vs. Boston Red Sox MLB game Friday night.",
#  "The 2025 fantasy baseball season just ended, but Eric Karabell is already thinking about 2026.",
#  "There's still a lot at stake entering the final weekend of the regular season. We have your guide to the last few days of baseball before October.",
#  "Twelve teams will enter October, but only one team will leave (with a ring). You can root for the three franchises that have never won a title before \u2026 or you can pull for the Yankees or Dodgers.",
#  "Apple TV+'s broadcast of the Boston Red Sox vs. Detroit Tigers game at Fenway Park tonight will incorporate live footage captured with the iPhone 17 Pro.\n\n\n\nImage Credit: Apple TV+\n\nApple says the iPhone 17 Pro will capture live gameplay, along with batting p\u2026"
# ]
# [
#  "Apple's",
#  "new",
#  "Pro",
#  "phone",
#  "will"
# ]

# %% [markdown]
# # Back to the slides

# %% [markdown]
# # Example 6. Creating a basic frequency distribution from the words in articles

# %%
from collections import Counter

for item in [authors, sources, words]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [(None, 16), ('Eric Karabell', 4), ('info@hypebeast.com (Hypebeast)', 4), ('Gael Cooper', 3), ('Alden Gonzalez', 3), ('ABC News', 3), ('ESPN Fantasy', 3), ('Benjamin Mayo', 2), ('Jake Rossen', 2), ('J.J. Post', 2)]
# [('ESPN', 30), ('Business Insider', 6), ('Forbes', 6), ('Fox Sports', 6), ('CNET', 5), ('MLB Trade Rumors', 5), ('NPR', 4), ('HYPEBEAST', 4), ('9to5Mac', 3), ('Gizmodo.com', 3)]
# [('the', 159), ('a', 75), ('of', 69), ('to', 58), ('and', 56), ('for', 38), ('in', 37), ('baseball', 32), ('The', 24), ('with', 24)]

# %% [markdown]
# # Example 7. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words),
                    ('Author', authors),
                    ('Source', sources)):
    pt = PrettyTable(field_names=[label, 'Count'])
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 from prettytable import PrettyTable
#       3 for label, data in (('Word', words),
#       4                     ('Author', authors),
#       5                     ('Source', sources)):
#       6     pt = PrettyTable(field_names=[label, 'Count'])
#
# ModuleNotFoundError: No module named 'prettytable'

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 8. Calculating lexical diversity for articles

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens)

# A function for computing the average number of words per tweet
def average_words(statuses):
    valid_statuses = [s for s in statuses if isinstance(s, str) and s.strip()]

    if not valid_statuses:
        return 0.0  # or handle however you prefer (e.g. return None)

    total_words = sum(len(s.split()) for s in valid_statuses)
    return total_words / len(valid_statuses)

print(lexical_diversity(words))
print(average_words(descriptions))
# Out:
# 0.5157522123893805
# 28.535353535353536

# %% [markdown]
# ## Back to slides

# %% [markdown]
# #  Example 9. Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
plt.show()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 639, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1985, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/m9/cwh1x1690_jdw4s6x8h_csfr0000gq/T/ipykernel_62720/3184200949.py", line 1, in <module>
#     import matplotlib
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py", line 159, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/rcsetup.py", line 28, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/colors.py", line 57, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/ticker.py", line 144, in <module>
#     from matplotlib import transforms as mtransforms
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import matplotlib
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:159
#     155 from packaging.version import parse as parse_version
#     157 # cbook must import matplotlib only within function
#     158 # definitions, so it is safe to import from it here.
# --> 159 from . import _api, _version, cbook, _docstring, rcsetup
#     160 from matplotlib.cbook import sanitize_sequence
#     161 from matplotlib._api import MatplotlibDeprecationWarning
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/rcsetup.py:28
#      26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
# ---> 28 from matplotlib.colors import Colormap, is_color_like
#      29 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      30 from matplotlib._enums import JoinStyle, CapStyle
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/colors.py:57
#      55 import matplotlib as mpl
#      56 import numpy as np
# ---> 57 from matplotlib import _api, _cm, cbook, scale
#      58 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      61 class _ColorMapping(dict):
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/ticker.py:144
#     142 import matplotlib as mpl
#     143 from matplotlib import _api, cbook
# --> 144 from matplotlib import transforms as mtransforms
#     146 _log = logging.getLogger(__name__)
#     148 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     149            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     150            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     156            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     157            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: initialization failed

# %% [markdown]
# # Back to the slides

# %% [markdown]
# # Example 10. Image segmentation using Hugging Face

# %%
# !pip install -q datasets transformers evaluate timm albumentations

# %%
from IPython.display import Image
image_urls = {}

for i in range(5):
  print(i)
  print(all_articles['articles'][i]['title'])
  try:
    image_url = all_articles['articles'][i]['urlToImage']
    article = all_articles['articles'][i]
    image = Image(url=image_url)
    display(image)
    image_urls[i] = image_url
  except ValueError:
    print('no image')

# %%
# Pick an image
image_url = image_urls[3]

# %%
from transformers import pipeline
import requests
from PIL import Image, ImageDraw

# %%
image = Image.open(requests.get(image_url, stream=True).raw)

# %%
#obj_detector = pipeline(task="object-detection")
obj_detector = pipeline(
    task="object-detection",
    model="facebook/detr-resnet-50"  # explicitly specify model
)
#https://huggingface.co/facebook/detr-resnet-50
#COCO2017 dataset contains 80 object categories
#https://tech.amikelive.com/node-718/what-object-categories-labels-are-in-coco-dataset/

# %%
results = obj_detector(image)

# %%
draw = ImageDraw.Draw(image)

for result in results:
    score, label, box = result["score"], result["label"], result["box"]
    x, y, x2, y2 = box['xmin'], box['ymin'], box['xmax'], box['ymax'],
    draw.rectangle((x, y, x2, y2), outline="red", width=1)
    draw.text((x, y), label, fill="white")

image
