# %% [markdown]
# # Example 1. Authorizing an application to access NewsAPI data

# %%
# !pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests<3.0.0 in /Users/caoguangjing/opt/anaconda3/lib/python3.9/site-packages (from newsapi-python) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/caoguangjing/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/caoguangjing/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/caoguangjing/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/caoguangjing/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (3.3)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7

# %%
from newsapi import NewsApiClient

# See https://newsapi.org/docs for more information
# on NewsAPI implementation.

API_KEY = '4199f4bb632f47cca033ed58a2532974'

newsapi = NewsApiClient(api_key=API_KEY)
print(newsapi)
# Out:
# <newsapi.newsapi_client.NewsApiClient object at 0x7fd2f00e5880>

# %% [markdown]
# # Back to slides

# %% [markdown]
# # Example 2.  All possible sources and retrieving top headlines

# %%
sources = newsapi.get_sources()

# %%
print(sources)
# Out:
# {'status': 'ok', 'sources': [{'id': 'abc-news', 'name': 'ABC News', 'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.', 'url': 'https://abcnews.go.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'abc-news-au', 'name': 'ABC News (AU)', 'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.", 'url': 'https://www.abc.net.au/news', 'category': 'general', 'language': 'en', 'country': 'au'}, {'id': 'aftenposten', 'name': 'Aftenposten', 'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.', 'url': 'https://www.aftenposten.no', 'category': 'general', 'language': 'no', 'country': 'no'}, {'id': 'al-jazeera-english', 'name': 'Al Jazeera English', 'description': 'News, analysis from the Middle East and worldwide, multimedia and interactives, opinions, documentaries, podcasts, long reads and broadcast schedule.', 'url': 'https://www.aljazeera.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'ansa', 'name': 'ANSA.it', 'description': 'Agenzia ANSA: ultime notizie, foto, video e approfondimenti su: cronaca, politica, economia, regioni, mondo, sport, calcio, cultura e tecnologia.', 'url': 'https://www.ansa.it', 'category': 'general', 'language': 'it', 'country': 'it'}, {'id': 'argaam', 'name': 'Argaam', 'description': 'ارقام موقع متخصص في متابعة سوق الأسهم السعودي تداول - تاسي - مع تغطيه معمقة لشركات واسعار ومنتجات البتروكيماويات , تقارير مالية الاكتتابات الجديده ', 'url': 'https://www.argaam.com', 'category': 'business', 'language': 'ar', 'country': 'sa'}, {'id': 'ars-technica', 'name': 'Ars Technica', 'description': "The PC enthusiast's resource. Power users and the tools they love, without computing religion.", 'url': 'https://arstechnica.com', 'category': 'technology', 'language': 'en', 'country': 'us'}, {'id': 'ary-news', 'name': 'Ary News', 'description': 'ARY News is a Pakistani news channel committed to bring you up-to-the minute Pakistan news and featured stories from around Pakistan and all over the world.', 'url': 'https://arynews.tv/ud/', 'category': 'general', 'language': 'ud', 'country': 'pk'}, {'id': 'associated-press', 'name': 'Associated Press', 'description': 'The AP delivers in-depth coverage on the international, politics, lifestyle, business, and entertainment news.', 'url': 'https://apnews.com/', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'australian-financial-review', 'name': 'Australian Financial Review', 'description': 'The Australian Financial Review reports the latest news from business, finance, investment and politics, updated in real time. It has a reputation for independent, award-winning journalism and is essential reading for the business and investor community.', 'url': 'http://www.afr.com', 'category': 'business', 'language': 'en', 'country': 'au'}, {'id': 'axios', 'name': 'Axios', 'description': 'Axios are a new media company delivering vital, trustworthy news and analysis in the most efficient, illuminating and shareable ways possible.', 'url': 'https://www.axios.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'bbc-news', 'name': 'BBC News', 'description': 'Use BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news.', 'url': 'https://www.bbc.co.uk/news', 'category': 'general', 'language': 'en', 'country': 'gb'}, {'id': 'bbc-sport', 'name': 'BBC Sport', 'description': 'The home of BBC Sport online. Includes live sports coverage, breaking news, results, video, audio and analysis on Football, F1, Cricket, Rugby Union, Rugby League, Golf, Tennis and all the main world sports, plus ma ...

# %%
top_headlines = newsapi.get_top_headlines(#q='bitcoin',
                                          #sources='bbc-news,the-verge',
                                          #category='business',
                                          language='en',
                                          country='us'
                                          )

# %%
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 36, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Anthony Faiola', 'title': 'In ‘historic moment,’ King Charles prays with Pope Leo at Sistine Chapel - The Washington Post', 'description': 'The royal visit to the Vatican marks the first time in nearly 500 years that a British monarch, head of the Anglican church, has prayed with a Roman Catholic pope.', 'url': 'https://www.washingtonpost.com/world/2025/10/23/king-charles-pope-leo-prayer/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/AFSJX6S6H77LF5T4IYOICLXZLM_size-normalized.jpg&w=1440', 'publishedAt': '2025-10-23T18:21:59Z', 'content': 'The royal visit to the Vatican marks the first time in nearly 500 years that a British monarch, head of the Anglican church, has prayed with a Roman Catholic pope.\r\nUpdated October 23, 2025 at 10:54 … [+30 chars]'}, {'source': {'id': 'abc-news', 'name': 'ABC News'}, 'author': 'ABC News - Breaking News, Latest News and Videos', 'title': 'Trump reverses decision to send troops to San Francisco after conversation with mayor - ABC News - Breaking News, Latest News and Videos', 'description': None, 'url': 'https://abcnews.go.com/US/trump-reverses-decision-send-troops-san-francisco-after/story?id\\\\u003d126805307', 'urlToImage': None, 'publishedAt': '2025-10-23T17:41:03Z', 'content': None}, {'source': {'id': None, 'name': 'Variety'}, 'author': 'Ethan Shanfeld', 'title': 'Isabelle Tate, ‘9-1-1: Nashville’ Actor, Dies at 23 - Variety', 'description': "Isabelle Tate, who played Julie on ABC's '9-1-1: Nashville,' has died. She was 23.", 'url': 'https://variety.com/2025/tv/news/isabelle-tate-dead-911-nashville-1236559891/', 'urlToImage': 'https://variety.com/wp-content/uploads/2025/10/Isabelle-Tate.jpg?w=1000&h=563&crop=1', 'publishedAt': '2025-10-23T17:41:00Z', 'content': 'Isabelle Tate, an actor on ABC’s “9-1-1: Nashville,” died on Sunday. She was 23.\r\nTate played Julie on the Ryan Murphy spinoff series, appearing in the pilot episode that aired on Oct. 9, 2025. Her r… [+1412 chars]'}, {'source': {'id': 'politico', 'name': 'Politico'}, 'author': 'Katherine Tully-McManus, Jordain Carney', 'title': 'Senate rejects pay plan for some federal workers - Politico', 'description': 'Democrats voted down the proposal from Sen. Ron Johnson after putting out their own plan.', 'url': 'https://www.politico.com/live-updates/2025/10/23/congress/senate-rejects-pay-plan-for-some-federal-workers-00620433', 'urlToImage': 'https://www.politico.com/dims4/default/f247d17/2147483647/resize/1200x/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2Fa3%2F8a%2F143a0e2d47b088c683be287fe3b0%2Fu-s-congress-05268.jpg', 'publishedAt': '2025-10-23T17:33:30Z', 'content': None}, {'source': {'id': 'techcrunch', 'name': 'TechCrunch'}, 'author': 'Sarah Perez', 'title': 'Microsoft’s Mico is a ‘Clippy’ for the AI era - TechCrunch', 'description': 'Microsoft has unveiled “Mico,” a new animated avatar for its Copilot AI that brings back shades of Clippy. The expressive blob acts as a friendly, customizable face for the chatbot.', 'url': 'https://techcrunch.com/2025/10/23/microsofts-mico-is-a-clippy-for-the-ai-era/', 'urlToImage': 'https://techcrunch.com/wp-content/uploads/2025/10/Mico-1.png?resize=1200,675', 'publishedAt': '2025-10-23T17:08:23Z', 'content': 'Microsoft has a new Clippy, and it’s an AI friend called Mico. At the company’s Copilot fall release press event on Thursday, the company introduced a range of new features and updates for its AI cha… [+3508 chars]'}, {'source': {'id': 'the-wall-street-journal', 'name': 'The Wall Street Journal'}, 'author': 'The Wall Street Journal', 'title': 'JB Pritzker Creates Watchdog for Federal Immigration Actions in Illinois - The Wall Street Journal', 'description': None, 'url': 'https://www.wsj.com/us-news/jb-pritzker-creates-watchdog-for-federal-immigration-actions-in- ...

# %% [markdown]
# # Saving data!
#
# Very important!
#
# ![important](https://media.istockphoto.com/photos/important-picture-id186613912?k=6&m=186613912&s=612x612&w=0&h=bMibIfwwjrEW93VWjr3f-wCJwrNn5nyX4TqfitGxwAk=)

# %%
# store data locally (if you run this code locally) 
# or store it temporary in the virtual machine (if you run this code in a cloud service such as google colab)
import json
data= json.dumps(top_headlines, indent=1)

file = open('foo.txt','w')
file.write(data)
file.close()

# %%
file = open('foo.txt','r')
foo = file.read()
d = json.loads(foo)

print(len(d['articles']))
for article in d['articles']:
  print(f"author: {article['author']}")
  print(f"title: {article['title']}")
  print(f"description: {article['description']}")
# Out:
# 14
# author: Anthony Faiola
# title: In ‘historic moment,’ King Charles prays with Pope Leo at Sistine Chapel - The Washington Post
# description: The royal visit to the Vatican marks the first time in nearly 500 years that a British monarch, head of the Anglican church, has prayed with a Roman Catholic pope.
# author: ABC News - Breaking News, Latest News and Videos
# title: Trump reverses decision to send troops to San Francisco after conversation with mayor - ABC News - Breaking News, Latest News and Videos
# description: None
# author: Ethan Shanfeld
# title: Isabelle Tate, ‘9-1-1: Nashville’ Actor, Dies at 23 - Variety
# description: Isabelle Tate, who played Julie on ABC's '9-1-1: Nashville,' has died. She was 23.
# author: Katherine Tully-McManus, Jordain Carney
# title: Senate rejects pay plan for some federal workers - Politico
# description: Democrats voted down the proposal from Sen. Ron Johnson after putting out their own plan.
# author: Sarah Perez
# title: Microsoft’s Mico is a ‘Clippy’ for the AI era - TechCrunch
# description: Microsoft has unveiled “Mico,” a new animated avatar for its Copilot AI that brings back shades of Clippy. The expressive blob acts as a friendly, customizable face for the chatbot.
# author: The Wall Street Journal
# title: JB Pritzker Creates Watchdog for Federal Immigration Actions in Illinois - The Wall Street Journal
# description: None
# author: None
# title: Portland Trail Blazers coach Chauncey Billups and Miami Heat player Terry Rozier arrested - BBC
# description: Dozens of people have been charged over two investigations in a crackdown on illegal gambling, says FBI.
# author: Samantha Delouya
# title: Mortgage rates fall to lowest level of 2025 - CNN
# description: Americans frustrated by high home borrowing rates may have gotten some welcome news this week.
# author: Andrew J. Hawkins
# title: Elon Musk says he needs $1 trillion to control Tesla’s ‘robot army’ - The Verge
# description: Tesla CEO Elon Musk urged shareholders to approve his massive pay package so he could ensure control over the company’s “robot army.”
# author: Jyoti Mann
# title: Meta told some employees their jobs are being replaced by tech — read the memo - businessinsider.com
# description: An internal memo explaining the cuts said "many routine decisions can now be handled efficiently by technology."
# author: Haley  Ott
# title: Vance says he was insulted by Israeli lawmakers' "very stupid political stunt" on West Bank annexation - CBS News
# description: Vice President Vance says he was insulted by Israeli lawmakers' "very stupid political stunt" with a vote on West Bank annexation.
# author: Fox Weather
# title: Bryan Norcross: Tropical Storm Melissa to begin intensifying soon - FOX Weather
# description: FOX Weather Hurricane Specialist Bryan Norcross provides his analysis of Tropical Storm Melissa. Melissa is forecast to begin the processes of intensifying and is expected to become a hurricane in the coming days, eventually reaching Category 3 or 4 strength.
# author: James Felton
# title: Interstellar Object 3I/ATLAS's Tail Appears To Have Changed Direction, Nordic Optical Telescope Finds - IFLScience
# description: "If the object is an alien spacecraft slowing down, and the anti-tail is braking thrust, then this change from anti-tail to tail would be entirely expected near perihelion," Avi Loeb wrote, but there is a better explanation.
# author: Skyler Ware
# title: Venomous snake strikes captured in extreme detail through high-speed videos for first time - Live Science
# description: Over 100 videos of venomous snake strikes reveal three different types of attacks, with some biting down several times "to prolong the venom flow into their prey."

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 3. Displaying API responses as pretty-printed JSON

# %%
import json
print(json.dumps(top_headlines, indent=1))
# Out:
# {
#  "status": "ok",
#  "totalResults": 36,
#  "articles": [
#   {
#    "source": {
#     "id": "the-washington-post",
#     "name": "The Washington Post"
#    },
#    "author": "Anthony Faiola",
#    "title": "In \u2018historic moment,\u2019 King Charles prays with Pope Leo at Sistine Chapel - The Washington Post",
#    "description": "The royal visit to the Vatican marks the first time in nearly 500 years that a British monarch, head of the Anglican church, has prayed with a Roman Catholic pope.",
#    "url": "https://www.washingtonpost.com/world/2025/10/23/king-charles-pope-leo-prayer/",
#    "urlToImage": "https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/AFSJX6S6H77LF5T4IYOICLXZLM_size-normalized.jpg&w=1440",
#    "publishedAt": "2025-10-23T18:21:59Z",
#    "content": "The royal visit to the Vatican marks the first time in nearly 500 years that a British monarch, head of the Anglican church, has prayed with a Roman Catholic pope.\r\nUpdated October 23, 2025 at 10:54 \u2026 [+30 chars]"
#   },
#   {
#    "source": {
#     "id": "abc-news",
#     "name": "ABC News"
#    },
#    "author": "ABC News - Breaking News, Latest News and Videos",
#    "title": "Trump reverses decision to send troops to San Francisco after conversation with mayor - ABC News - Breaking News, Latest News and Videos",
#    "description": null,
#    "url": "https://abcnews.go.com/US/trump-reverses-decision-send-troops-san-francisco-after/story?id\\\\u003d126805307",
#    "urlToImage": null,
#    "publishedAt": "2025-10-23T17:41:03Z",
#    "content": null
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Variety"
#    },
#    "author": "Ethan Shanfeld",
#    "title": "Isabelle Tate, \u20189-1-1: Nashville\u2019 Actor, Dies at 23 - Variety",
#    "description": "Isabelle Tate, who played Julie on ABC's '9-1-1: Nashville,' has died. She was 23.",
#    "url": "https://variety.com/2025/tv/news/isabelle-tate-dead-911-nashville-1236559891/",
#    "urlToImage": "https://variety.com/wp-content/uploads/2025/10/Isabelle-Tate.jpg?w=1000&h=563&crop=1",
#    "publishedAt": "2025-10-23T17:41:00Z",
#    "content": "Isabelle Tate, an actor on ABC\u2019s \u201c9-1-1: Nashville,\u201d died on Sunday. She was 23.\r\nTate played Julie on the Ryan Murphy spinoff series, appearing in the pilot episode that aired on Oct. 9, 2025. Her r\u2026 [+1412 chars]"
#   },
#   {
#    "source": {
#     "id": "politico",
#     "name": "Politico"
#    },
#    "author": "Katherine Tully-McManus, Jordain Carney",
#    "title": "Senate rejects pay plan for some federal workers - Politico",
#    "description": "Democrats voted down the proposal from Sen. Ron Johnson after putting out their own plan.",
#    "url": "https://www.politico.com/live-updates/2025/10/23/congress/senate-rejects-pay-plan-for-some-federal-workers-00620433",
#    "urlToImage": "https://www.politico.com/dims4/default/f247d17/2147483647/resize/1200x/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2Fa3%2F8a%2F143a0e2d47b088c683be287fe3b0%2Fu-s-congress-05268.jpg",
#    "publishedAt": "2025-10-23T17:33:30Z",
#    "content": null
#   },
#   {
#    "source": {
#     "id": "techcrunch",
#     "name": "TechCrunch"
#    },
#    "author": "Sarah Perez",
#    "title": "Microsoft\u2019s Mico is a \u2018Clippy\u2019 for the AI era - TechCrunch",
#    "description": "Microsoft has unveiled \u201cMico,\u201d a new animated avatar for its Copilot AI that brings back shades of Clippy. The expressive blob acts as a friendly, customizable face for the chatbot.",
#    "url": "https://techcrunch.com/2025/10/23/microsofts-mico-is-a-clippy-for-the-ai-era/",
#    "urlToImage": "https://techcrunch.com/wp-content/uploads/2025/10/Mico-1.png?resize=1200,675",
#    "publishedAt": "2025-10-23T17:08:23Z",
#    "content": "Microsoft has a new Clippy, and it\u2019s an AI friend called Mico. At the company\u2019s Copilot fall release press event on Thursday, the company introduced a range of new features and updates for its AI cha\u2026 [+3508 chars]"
#   },
#   {
#    "source": {
#     "id": "the-wall-street-journal",
#     "name": "The Wall Street Journal"
#    },
#    "author": "The Wall Street Journal",
#    "title": "JB Pritzker Creates Watchdog for Federal Immigration Actions in Illinois - The Wall Street Journal",
#    "description": null,
#    "url": "https://www.wsj.com/us-news/jb-pritzker-creates-watchdog-for-federal-immigration-actions-in-illinois-174f4ab7",
#    "urlToImage": null,
#    "publishedAt": "2025-10-23T16:35:00Z",
#    "content": null
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "BBC News"
#    },
#    "author": null,
#    "title": "Portland Trail Blazers coach Chauncey Billups and Miami Heat player Terry Rozier arrested - BBC",
#    "description": "Dozens of people have been charged over two investigations in a crackdown on illegal gambling, says FBI.",
#    "url": "https://www.bbc.com/news/articles/cvgmpp3x5x5o",
#    "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/36e0/live/74d4bdf0-b010-11f0-8317-a7963fdcfd4f.jpg",
#    "publishedAt": "2025-10-23T16:19:07Z",
#    "content": "A National Basketball Association player and coach are among dozens of people charged in two investigations centred on illegal sports betting and mafia-linked poker games, the FBI has announced. \r\nMi\u2026 [+4404 chars]"
#   },
#   {
#    "source": {
#     "id": "cnn",
#     "name": "CNN"
#    },
#    "author": "Samantha Delouya",
#    "title": "Mortgage rates fall to lowest level of 2025 - CNN",
#    "description": "Americans frustrated by high home borrowing rates may have gotten some welcome news this week.",
#    "url": "https://www.cnn.com/2025/10/23/economy/us-mortgage-rates",
#    "urlToImage": "https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2230496396.jpg?c=16x9&q=w_800,c_fill",
#    "publishedAt": "2025-10-23T16:00:51Z",
#    "content": "Americans frustrated by high home borrowing rates may have gotten some welcome news this week.\r\nThe average 30-year fixed mortgage rate dropped to 6.19% for the week ending October 23, down from 6.27\u2026 [+2157 chars]"
#   },
#   {
#    "source": {
#     "id": "the-verge",
#     "name": "The Verge"
#    },
#    "author": "Andrew J. Hawkins",
#    "title": "Elon Musk says he needs $1 trillion to control Tesla\u2019s \u2018robot army\u2019 - The Verge",
#    "description": "Tesla CEO Elon Musk urged shareholders to approve his massive pay package so he could ensure control over the company\u2019s \u201crobot army.\u201d",
#    "url": "https://www.theverge.com/transportation/805247/tesla-q3-earnings-elon-musk-robot-army-pay-package",
#    "urlToImage": "https://platform.theverge.com/wp-content/uploads/sites/2/2025/04/STK171_VRG_Illo_16_Normand_ElonMusk_16.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200",
#    "publishedAt": "2025-10-23T15:57:50Z",
#    "content": "<ul><li></li><li></li><li></li></ul>\r\nTesla shareholders will decide whether Musk deserves his money, and his robot army, at an upcoming meeting.\r\nTesla shareholders will decide whether Musk deserves\u2026 [+6416 chars]"
#   },
#   {
#    "source": {
#     "id": "business-insider",
#     "name": "Business Insider"
#    },
#    "author": "Jyoti Mann",
#    "title": "Meta told some employees their jobs are being replaced by tech \u2014 read the memo - businessinsider.com",
#    "description": "An internal memo explaining the cuts said \"many routine decisions can now be handled efficiently by technology.\"",
#    "url": "https://www.businessinsider.com/meta-job-cuts-risk-org-replaced-by-tech-layoffs-2025-10",
#    "urlToImage": "https://i.insider.com/68fa3cdcc007ca8c27377dc6?width=1200&format=jpeg",
#    "publishedAt": "2025-10-23T15:41:00Z",
#    "content": "Meta this week told staff in its risk division that a number of their roles were being eliminated because of improvements in the company's internal technology, Business Insider has learned.\r\nMeta's c\u2026 [+5430 chars]"
#   },
#   {
#    "source": {
#     "id": "cbs-news",
#     "name": "CBS News"
#    },
#    "author": "Haley  Ott",
#    "title": "Vance says he was insulted by Israeli lawmakers' \"very stupid political stunt\" on West Bank annexation - CBS News",
#    "description": "Vice President Vance says he was insulted by Israeli lawmakers' \"very stupid political stunt\" with a vote on West Bank annexation.",
#    "url": "https://www.cbsnews.com/news/vance-israel-insulted-west-bank-annexation-knesset-vote/",
#    "urlToImage": "https://assets1.cbsnewsstatic.com/hub/i/r/2025/10/23/c256aa9f-d74f-42ac-bc09-3a1104bd4263/thumbnail/1200x630g2/f7b3b4994d0b6f12525cb205b249d62e/vance-israel-2242216502.jpg",
#    "publishedAt": "2025-10-23T15:36:21Z",
#    "content": "Vice President JD Vance criticized on Thursday a vote by the Israeli parliament to advance a bill on the proposed annexation of the occupied West Bank, calling it \"a very stupid political stunt.\"\r\n\"I\u2026 [+2819 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Foxweather.com"
#    },
#    "author": "Fox Weather",
#    "title": "Bryan Norcross: Tropical Storm Melissa to begin intensifying soon - FOX Weather",
#    "description": "FOX Weather Hurricane Specialist Bryan Norcross provides his analysis of Tropical Storm Melissa. Melissa is forecast to begin the processes of intensifying and is expected to become a hurricane in the coming days, eventually reaching Category 3 or 4 strength.",
#    "url": "https://www.foxweather.com/watch/fmc-y3m1fq1tgs23t79m",
#    "urlToImage": "https://images.foxweather.com/static-media.fox.com/fmc/prod/weather/VX-14455176/992/558/fnqswy2lzoy6zk6c.jpg?ve=1&tl=1",
#    "publishedAt": "2025-10-23T15:26:38Z",
#    "content": null
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "IFLScience"
#    },
#    "author": "James Felton",
#    "title": "Interstellar Object 3I/ATLAS's Tail Appears To Have Changed Direction, Nordic Optical Telescope Finds - IFLScience",
#    "description": "\"If the object is an alien spacecraft slowing down, and the anti-tail is braking thrust, then this change from anti-tail to tail would be entirely expected near perihelion,\" Avi Loeb wrote, but there is a better explanation.",
#    "url": "https://www.iflscience.com/interstellar-object-3iatlass-tail-appears-to-have-changed-direction-81295",
#    "urlToImage": "https://assets.iflscience.com/assets/articleNo/81295/aImg/87173/comet-meta.png",
#    "publishedAt": "2025-10-23T14:04:42Z",
#    "content": "New observations from the Nordic Optical Telescope, in the Canary Islands, Spain, suggest that 3I/ATLAS's unusual anti-solar tail has changed direction, becoming dominated by a tail that faces away f\u2026 [+6452 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Live Science"
#    },
#    "author": "Skyler Ware",
#    "title": "Venomous snake strikes captured in extreme detail through high-speed videos for first time - Live Science",
#    "description": "Over 100 videos of venomous snake strikes reveal three different types of attacks, with some biting down several times \"to prolong the venom flow into their prey.\"",
#    "url": "https://www.livescience.com/animals/snakes/venomous-snake-strikes-captured-in-extreme-detail-through-high-speed-videos-for-first-time",
#    "urlToImage": "https://cdn.mos.cms.futurecdn.net/PUac6FDdBTw3xLEm38i5mh.gif",
#    "publishedAt": "2025-10-23T14:00:00Z",
#    "content": "Scientists finally know how venomous snakes sink their teeth into prey thanks to a series of high-speed videos.\r\nIn a new study, published Thursday (Oct. 23) in the Journal of Experimental Biology\r\n,\u2026 [+3355 chars]"
#   }
#  ]
# }

# %%
for i in range(5):
    print(top_headlines['articles'][i]['url'])
# Out:
# https://www.washingtonpost.com/world/2025/10/23/king-charles-pope-leo-prayer/
# https://abcnews.go.com/US/trump-reverses-decision-send-troops-san-francisco-after/story?id\\u003d126805307
# https://variety.com/2025/tv/news/isabelle-tate-dead-911-nashville-1236559891/
# https://www.politico.com/live-updates/2025/10/23/congress/senate-rejects-pay-plan-for-some-federal-workers-00620433
# https://techcrunch.com/2025/10/23/microsofts-mico-is-a-clippy-for-the-ai-era/

# %%
from IPython.display import Image
from IPython.core.display import HTML

for i in range(5):
  print(top_headlines['articles'][i]['title'])
  try:
    image = Image(url=top_headlines['articles'][i]['urlToImage'])
    display(image)
  except ValueError:
    print('no image')
# Out:
# In ‘historic moment,’ King Charles prays with Pope Leo at Sistine Chapel - The Washington Post
# <img src="https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/AFSJX6S6H77LF5T4IYOICLXZLM_size-normalized.jpg&w=1440"/>
# Trump reverses decision to send troops to San Francisco after conversation with mayor - ABC News - Breaking News, Latest News and Videos
# no image
# Isabelle Tate, ‘9-1-1: Nashville’ Actor, Dies at 23 - Variety
# <img src="https://variety.com/wp-content/uploads/2025/10/Isabelle-Tate.jpg?w=1000&h=563&crop=1"/>
# Senate rejects pay plan for some federal workers - Politico
# <img src="https://www.politico.com/dims4/default/f247d17/2147483647/resize/1200x/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2Fa3%2F8a%2F143a0e2d47b088c683be287fe3b0%2Fu-s-congress-05268.jpg"/>
# Microsoft’s Mico is a ‘Clippy’ for the AI era - TechCrunch
# <img src="https://techcrunch.com/wp-content/uploads/2025/10/Mico-1.png?resize=1200,675"/>

# %% [markdown]
# # Example 4. Collecting search results

# %%
#  Set this variable to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

#q = 'ai'
#q = 'data science'
#q = 'toyota'
q = 'baseball'

all_articles = newsapi.get_everything(q=q,
                                      #sources='bbc-news,the-verge',
                                      #domains='bbc.co.uk,techcrunch.com',
                                      from_param='2025-09-24',
                                      to='2025-10-08',
                                      language='en',
                                      sort_by='relevancy',
                                      #page=2
                                      )

# Show one sample search result by slicing the list...
print(json.dumps(all_articles, indent=4))
# Out:
# {
#     "status": "ok",
#     "totalResults": 3363,
#     "articles": [
#         {
#             "source": {
#                 "id": null,
#                 "name": "CNET"
#             },
#             "author": "Mike Sorrentino",
#             "title": "Fenway Park Gets a New Broadcast Player: iPhone 17 Pro Covering the Tigers, Red Sox Game",
#             "description": "Apple's new Pro phone will be used to film the Detroit Tigers vs. Boston Red Sox MLB game Friday night.",
#             "url": "https://www.cnet.com/tech/mobile/fenway-park-gets-a-new-broadcast-player-iphone-17-pro-covering-the-tigers-red-sox-game/",
#             "urlToImage": "https://www.cnet.com/a/img/resize/b271c8302925c007588ab5ab302ade596f5eb4cf/hub/2025/09/26/f856d7a5-4e87-4682-940d-ac61a401c447/friday-night-baseball-shot-on-iphone-17-pro-4.jpg?auto=webp&fit=crop&height=675&width=1200",
#             "publishedAt": "2025-09-26T18:21:45Z",
#             "content": "Apple's iPhone 17 Pro will be joining the traditional cameras that will shoot Friday's Detroit Tigers and Boston Red Sox baseball game Friday night.\r\nThe baseball game is being broadcast on Apple TV \u2026 [+2251 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Eric Karabell",
#             "title": "Way-too-early 2026 top-50 rankings",
#             "description": "The 2025 fantasy baseball season just ended, but Eric Karabell is already thinking about 2026.",
#             "url": "https://www.espn.com/fantasy/baseball/story/_/id/46475434/fantasy-baseball-2026-espn-preview-rankings-early-top-50-players-karabell",
#             "urlToImage": "https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1003%2Fr1554911_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-10-03T17:05:05Z",
#             "content": "It may be boring, but good luck finding legitimate reasons to avoid taking Los Angeles Dodgers DH/SP Shohei Ohtani and New York Yankees OF Aaron Judge with the first picks in 2026 fantasy baseball dr\u2026 [+8132 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "David Schoenfield",
#             "title": "From unsettled playoff races to home run records: What to watch in MLB's final weekend",
#             "description": "There's still a lot at stake entering the final weekend of the regular season. We have your guide to the last few days of baseball before October.",
#             "url": "https://www.espn.com/mlb/story/_/id/46346881/mlb-2025-regular-season-final-weekend-guide-watch-playoffs",
#             "urlToImage": "https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0925%2Fr1551075_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-26T11:20:40Z",
#             "content": "We made it to the final weekend of the 2025 MLB regular season.\r\nIt has been one wild, fun ride, especially if you're a fan of the Milwaukee Brewers or Seattle Mariners or Cleveland Guardians -- less\u2026 [+12625 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "NPR"
#             },
#             "author": "Becky Sullivan",
#             "title": "The MLB postseason begins Tuesday. Who should you root for to win a World Series?",
#             "description": "Twelve teams will enter October, but only one team will leave (with a ring). You can root for the three franchises that have never won a title before \u2026 or you can pull for the Yankees or Dodgers.",
#             "url": "https://www.npr.org/2025/09/30/nx-s1-5557394/mlb-2025-playoffs-yankees-red-sox-brewers-padres-mariners",
#             "urlToImage": "https://npr.brightspotcdn.com/dims3/default/strip/false/crop/2957x1663+0+0/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F11%2Ffa%2F962e87ab4ded9bd35ecce44a1ba1%2Fgettyimages-2237657411.jpg",
#             "publishedAt": "2025-09-30T09:00:00Z",
#             "content": "October baseball is here a day early, with Major League Baseball's first postseason games scheduled to begin Tuesday afternoon.\r\nIt's a wide-open field this postseason with no clear favorites like la\u2026 [+7475 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "MacRumors"
#             },
#             "author": "Joe Rossignol",
#             "title": "Red Sox vs. Tigers Game on Apple TV+ Tonight Will Be Partly Shot on iPhone 17 Pro",
#             "description": "Apple TV+'s broadcast of the Boston Red Sox vs. Detroit Tigers game at Fenway Park tonight will incorporate live footage captured with the iPhone 17 Pro.\n\n\n\nImage Credit: Apple TV+\n\nApple says the iPhone 17 Pro will capture live gameplay, along with batting p\u2026",
#             "url": "https://www.macrumors.com/2025/09/26/apple-tv-plus-red-sox-vs-tigers-iphone-17-pro/",
#             "urlToImage": "https://images.macrumors.com/t/6FevWkkQMKC5QfY6j0z_gLW1-Iw=/1600x/article-new/2025/09/iPhone-17-Pro-MLB-Rig.jpg",
#             "publishedAt": "2025-09-26T15:04:34Z",
#             "content": "Apple TV+'s broadcast of the Boston Red Sox vs. Detroit Tigers game at Fenway Park tonight will incorporate live footage captured with the iPhone 17 Pro.\r\nApple says the iPhone 17 Pro will capture li\u2026 [+616 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "CNET"
#             },
#             "author": "Gael Cooper",
#             "title": "Today's NYT Connections: Sports Edition Hints and Answers for Sept. 25, #367",
#             "description": "Here's today's Connections: Sports Edition answer and hints for groups. These clues will help you solve The New York Times' popular puzzle game, Connections: Sports Edition, every day.",
#             "url": "https://www.cnet.com/tech/gaming/todays-nyt-connections-sports-edition-hints-and-answers-for-sept-25-367/",
#             "urlToImage": "https://www.cnet.com/a/img/resize/b6a176556f33d8a7a6d33d6575c828a27a02cb83/hub/2024/10/16/c34cfc41-01f2-4b1a-80a8-f6479c50c02e/connections-sports-edition-6859.jpg?auto=webp&fit=crop&height=675&width=1200",
#             "publishedAt": "2025-09-24T20:32:21Z",
#             "content": "Looking for the most recent\u00a0regular Connections answers? Click here for today's Connections hints, as well as our daily answers and hints for The New York Times Mini Crossword, Wordle and Strands puz\u2026 [+1919 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "CNET"
#             },
#             "author": "Matt Elliott",
#             "title": "MLB Playoffs 2025: How to Watch, Stream the Wild Card Games Today",
#             "description": "Postseason baseball starts Tuesday with four, best-of-three Wild Cards series, and you don't need cable to watch.",
#             "url": "https://www.cnet.com/tech/services-and-software/mlb-playoffs-2025-how-to-watch-stream-the-wild-card-games-today/",
#             "urlToImage": "https://www.cnet.com/a/img/resize/0eb3ca55bb8d0472aa16207be2326d12f82861b3/hub/2025/09/30/10d1c0f5-d0a9-4705-b56f-3e36b2749f43/gettyimages-2229255201.jpg?auto=webp&fit=crop&height=675&width=1200",
#             "publishedAt": "2025-09-30T16:31:25Z",
#             "content": "October baseball arrives a day early this year. After a 162-game season that began back in March, the playoff field of 12 teams is set. Eight of these 12 playoff teams are in action starting today fo\u2026 [+3174 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "CNET"
#             },
#             "author": "Gael Cooper",
#             "title": "Today's NYT Mini Crossword Answers for Wednesday, Sept. 24",
#             "description": "Here's today's NYT Mini Crossword answer. These answers will help you solve New York Times' popular crossword game, Mini Crossword, every day!",
#             "url": "https://www.cnet.com/tech/gaming/todays-nyt-mini-crossword-answers-for-wednesday-sept-24/",
#             "urlToImage": "https://www.cnet.com/a/img/resize/4a7dc34963db8f9a51abae1ab77ec99b498be36f/hub/2024/07/25/50d61b9b-1c76-4678-9a92-f6eca531f4a8/nyt-mini-crossword-234876.jpg?auto=webp&fit=crop&height=675&width=1200",
#             "publishedAt": "2025-09-24T03:20:00Z",
#             "content": "Looking for\u00a0the most recent\u00a0Mini Crossword answer?\u00a0Click here for today's Mini Crossword hints, as well as our daily answers and hints for The New York Times Wordle, Strands, Connections and Connecti\u2026 [+1400 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Dodgers stay playoff perfect, take 2-0 NLDS lead",
#             "description": "After breezing past the Cincinnati Reds in the wild-card round, the world champion-Los Angeles Dodgers have kept up the momentum against the Phillies, and with Monday's Game 2 victory in Philadelphia, they now have a commanding 2-0 NLDS advantage.",
#             "url": "https://www.espn.com/mlb/story/_/id/46514611/dodgers-outlast-phillies-take-commanding-2-0-nlds-lead",
#             "urlToImage": "https://a.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1007%2Fr1556736_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-10-07T01:24:44Z",
#             "content": "PHILADELPHIA -- Will Smith drove in two runs in support of Blake Snell, who tossed six masterful innings of one-hit baseball, and the Los Angeles Dodgers outlasted the Philadelphia Phillies, 4-3, in \u2026 [+384 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "9to5Mac"
#             },
#             "author": "Benjamin Mayo",
#             "title": "Friday Night Baseball to feature footage shot on iPhone cameras, a first for a live sports broadcast",
#             "description": "Tonight\u2019s Friday Night Baseball game will feature some new camera angles, courtesy of iPhone 17 Pro. For the first time for a professional live sports broadcast, iPhones will be used to help capture the action. \n\n\n\nAt the Fenway Park game between Tigers and t\u2026",
#             "url": "https://9to5mac.com/2025/09/26/iphone-17-pro-mlb-friday-night-baseball/",
#             "urlToImage": "https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2025/09/17-pro-mlb-friday-night-baseball.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1",
#             "publishedAt": "2025-09-26T11:00:00Z",
#             "content": "Tonight\u2019s Friday Night Baseball game will feature some new camera angles, courtesy of iPhone 17 Pro. For the first time for a professional live sports broadcast, iPhones will be used to help capture \u2026 [+1760 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Mental Floss"
#             },
#             "author": "Jake Rossen",
#             "title": "Why Does \u2018Ballpark Figure\u2019 Mean \u201ca Rough Estimate\u201d?",
#             "description": "The popular baseball idiom for a rough estimate has been around for decades. But who coined it?",
#             "url": "https://www.mentalfloss.com/sports/baseball/why-does-ballpark-figure-mean-a-rough-estimate",
#             "urlToImage": "https://images2.minutemediacdn.com/image/upload/c_crop,x_0,y_327,w_4955,h_2787/c_fill,w_1440,ar_1440:810,f_auto,q_auto,g_auto/images/GettyImages/mmsport/mentalfloss/01k48ntvz36f7k03ct18.jpg",
#             "publishedAt": "2025-09-28T15:03:00Z",
#             "content": "Anyone who has ever had a skilled laborer eyeball a plumbing problem or had a body shop assess car damage is probably familiar with the phrase ballpark figure. Its what you ask for when you want a ro\u2026 [+4772 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Mental Floss"
#             },
#             "author": "Jake Rossen",
#             "title": "Why Does \u2018Ballpark Figure\u2019 Mean \u201ca Rough Estimate\u201d?",
#             "description": "The popular baseball idiom for a rough estimate has been around for decades. But who coined it?",
#             "url": "https://www.mentalfloss.com/sports/why-does-ballpark-figure-mean-a-rough-estimate",
#             "urlToImage": "https://images2.minutemediacdn.com/image/upload/c_crop,x_0,y_327,w_4955,h_2787/c_fill,w_1440,ar_1440:810,f_auto,q_auto,g_auto/images/GettyImages/mmsport/mentalfloss/01k48ntvz36f7k03ct18.jpg",
#             "publishedAt": "2025-09-28T15:03:00Z",
#             "content": "Anyone who has ever had a skilled laborer eyeball a plumbing problem or had a body shop assess car damage is probably familiar with the phrase ballpark figure. Its what you ask for when you want a ro\u2026 [+4772 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Uncrate.com"
#             },
#             "author": "Uncrate",
#             "title": "Garb: Black Heart",
#             "description": "Imogene + Willie Heart Tee / $68. SLNT Expanded Waterproof Faraday Backpack / $300. Luca Faloni Cashmere Baseball Cap / $275. Imogene + Willie Military Trousers / $195. Kleman Traverse Boots / $245. Timex Q 1975 Enigma Watch / $209....",
#             "url": "https://uncrate.com/garb-black-heart/",
#             "urlToImage": "https://uncrate.com/assets_c/2025/10/Garb-Black-Heart-darkened-thumb-1920xauto-186015.jpg",
#             "publishedAt": "2025-10-07T21:00:12Z",
#             "content": "Face the day with ResponsibleMan: a no-frills, physician-formulated line of men's daily supplements engineered for clarity, strength, and grit. Led by the Emerson multivitaminhoused in a sleek black \u2026 [+461 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Alden Gonzalez",
#             "title": "No team has repeated in a quarter century. Are the Dodgers different?",
#             "description": "Not since the 2000 Yankees has a team won back-to-back World Series. What does that mean for L.A.?",
#             "url": "https://www.espn.com/mlb/story/_/id/46466643/mlb-2025-playoffs-los-angeles-dodgers-repeat-champions-world-series-challenges",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1003%2Fr1554779_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-10-03T12:23:56Z",
#             "content": "WHEN THE LOW point arrived last year, on Sept. 15 in Atlanta, Los Angeles Dodgers manager Dave Roberts broke character and challenged some of his players in a meeting many of them later identified as\u2026 [+12718 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Daringfireball.net"
#             },
#             "author": "John Gruber",
#             "title": "The Talk Show: \u2018Iconic Pig Lipstick\u2019",
#             "description": null,
#             "url": "https://daringfireball.net/thetalkshow/2025/09/30/ep-431",
#             "urlToImage": null,
#             "publishedAt": "2025-10-01T03:00:06Z",
#             "content": "John Moltz returns to the show to talk about the iPhone 17 lineup: the iPhone 17 Pro and Pro Max, iPhone 17, and the no-number iPhone Air. Not one word about baseball, but some Star Wars talk may or \u2026 [+495 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "HYPEBEAST"
#             },
#             "author": "info@hypebeast.com (Hypebeast)",
#             "title": "Fear of God Presents Collection Nine of Menswear",
#             "description": "SummaryFear of God Collection Nine is inspired by the cultural significance of baseball, a theme Jerry Lorenzo calls a symbol of completionThe apparel blends sophisticated Italian tailoring with sporty silhouettes, including Yankee pinstriped sweatpantsThe dr\u2026",
#             "url": "https://hypebeast.com/2025/10/fear-of-god-collection-nine-menswear-lookbook-release-info",
#             "urlToImage": "https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2025%2F10%2F03%2Ffear-of-god-collection-nine-menswear-lookbook-release-infotw.jpg?w=1080&cbr=1&q=90&fit=max",
#             "publishedAt": "2025-10-03T09:45:37Z",
#             "content": "Summary\r\n<ul><li>Fear of God Collection Nine is inspired by the cultural significance of baseball, a theme Jerry Lorenzo calls a symbol of completion</li><li>The apparel blends sophisticated Italian \u2026 [+1687 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Schumaker to manage Rangers on 4-year deal",
#             "description": "Skip Schumaker, the 2023 National League Manager of the Year with the Marlins, was hired as Rangers manager, agreeing Friday night on a four-year contract.",
#             "url": "https://www.espn.com/mlb/story/_/id/46481090/rangers-hire-skip-schumaker-manager-four-year-deal",
#             "urlToImage": "https://a2.espncdn.com/combiner/i?img=%2Fphoto%2F2024%2F0928%2Fr1392861_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-10-04T01:20:52Z",
#             "content": "ARLINGTON, Texas -- The Rangers hired Skip Schumaker as their manager, agreeing Friday night on a four-year contract with the former National League Manager of the Year.\r\nSchumaker's deal was announc\u2026 [+1124 chars]"
#         },
#         {
#             "source": {
#                 "id": "business-insider",
#                 "name": "Business Insider"
#             },
#             "author": "Henry Chandonnet",
#             "title": "AI status symbols are popping up everywhere",
#             "description": "Fans lined up for free \"thinking\" caps from Anthropic. OpenAI handed out specialty token plaques. Cursor mailed tab buttons.",
#             "url": "https://www.businessinsider.com/ai-status-symbols-openai-anthropic-cursor-2025-10",
#             "urlToImage": "https://i.insider.com/68e57f20cc993f9955cfb9d5?width=1200&format=jpeg",
#             "publishedAt": "2025-10-08T09:59:01Z",
#             "content": "OpenAI, Anthropic, and Cursor have recently debuted new limited-edition merchandise.Jeff Barg; Sunita Mohanty; Elie Steinbock\r\n<ul><li>Fans lined up for \"thinking\" caps from Anthropic, and OpenAI han\u2026 [+6883 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Guardians overtake Tigers with historical surge",
#             "description": "The Guardians became the first MLB team to overcome a deficit of 15 1/2 games and take the lead in either division or league play, beating Detroit to take a one-game lead.",
#             "url": "https://www.espn.com/mlb/story/_/id/46371907/guardians-overtake-tigers-historical-surge-lead-al-central",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0925%2Fr1550703_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-25T02:50:39Z",
#             "content": "Sep 24, 2025, 10:37 PM ET\r\nCLEVELAND -- George Valera hit a two-run homer in the third inning, Jose Ram\u00edrez had a two-run double in the seventh and the Cleveland Guardians became the first major leag\u2026 [+1589 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "J.J. Post",
#             "title": "Springer's Hartford Whalers batting gloves to be donated to Hockey Hall of Fame",
#             "description": "The veteran Toronto Blue Jays outfielder is a native of New Britain, Connecticut, located approximately 20 minutes from the Whalers' former home.",
#             "url": "https://www.espn.com/mlb/story/_/id/46438272/george-springer-toronto-blue-jays-hartford-whalers-batting-gloves-hall-fame",
#             "urlToImage": "https://a2.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0930%2Fr1553471_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-30T21:22:33Z",
#             "content": "Come the end of the Toronto Blue Jays' season, veteran outfielder George Springer's batting gloves will have a new home -- but they won't be going far.\r\nEditor's Picks\r\nSpringer's Hartford Whalers-th\u2026 [+1378 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "J.J. Post",
#             "title": "Phillies' 9-9-9 Challenge box for 2025 postseason to feature 'fun size' hot dogs",
#             "description": "The Phillies' Challenge box will offer \"fun size\" hot dogs and \"petite\" beers, as well as a built-in scoreboard for fans to track their progress.",
#             "url": "https://www.espn.com/mlb/story/_/id/46478389/philadelphia-phillies-challenge-box-2025-postseason",
#             "urlToImage": "https://a3.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1003%2Fr1555075_1080x608_16%2D9.jpg",
#             "publishedAt": "2025-10-03T22:51:22Z",
#             "content": "If you're interested in attempting the famed 9-9-9 Challenge at a Philadelphia Phillies game this postseason, the club has you covered with a ready-made kit ... sort of.\r\nEditor's Picks\r\nConfused as \u2026 [+1251 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "NPR"
#             },
#             "author": "Alana Wise",
#             "title": "Random act of kindness: Mariners fan gifts historic ball to young stranger",
#             "description": "A fan caught Cal Raleigh's history-making 60th home run ball. He promptly turned the valuable memento over to 12-year-old Marcus Ruelos.",
#             "url": "https://www.npr.org/2025/09/26/nx-s1-5554385/mariners-fan-baseball-cal-raleigh-60th-home-run",
#             "urlToImage": "https://npr.brightspotcdn.com/dims3/default/strip/false/crop/4284x2410+0+1651/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F75%2Fd0%2Fe23447fd438c84aee9f52ec99c99%2Fimg-3001.jpg",
#             "publishedAt": "2025-09-26T17:26:28Z",
#             "content": "Marcus Ruelos and his dad Galan hoped to see something special when they went to the Seattle Mariners vs. Colorado Rockies game on Wednesday night, but they never thought they would be a part of the \u2026 [+2989 chars]"
#         },
#         {
#             "source": {
#                 "id": "business-insider",
#                 "name": "Business Insider"
#             },
#             "author": "Alice Tecotzky",
#             "title": "Stars, stripes, and kilts: The wildest looks at the Ryder Cup",
#             "description": "Business Insider was at the Ryder Cup on Friday, where some full-body American flags outfits and group costumes instead of the typical golf polo.",
#             "url": "https://www.businessinsider.com/ryder-cup-fashion-outfits-photos-2025-9",
#             "urlToImage": "https://i.insider.com/68d6d940cc993f9955cf05b5?width=1200&format=jpeg",
#             "publishedAt": "2025-09-26T19:41:28Z",
#             "content": "This group isn't sure whether they'll keep the outfits.Alice Tecotzky\r\n<ul><li>Some spectators ditched their typical Friday workwear for flamboyant outfits at the Ryder Cup.</li><li>Business Insider \u2026 [+3445 chars]"
#         },
#         {
#             "source": {
#                 "id": "business-insider",
#                 "name": "Business Insider"
#             },
#             "author": "Catherine Work",
#             "title": "I email my 106-year-old grandmother every Friday. It's one of the most meaningful commitments I've ever made.",
#             "description": "Two years ago, I started the tradition of emailing my grandma every week. Our messages help us stay connected despite the distance between us.",
#             "url": "https://www.businessinsider.com/email-grandma-weekly-stay-connected-despite-distance-2025-9",
#             "urlToImage": "https://i.insider.com/68bf38d332af4d666ef77b6e?width=1188&format=jpeg",
#             "publishedAt": "2025-09-24T12:37:02Z",
#             "content": "Emailing my grandmother every week is a tradition that helps us stay connected despite the distance.Catherine Work\r\n<ul><li>Two years ago, I came up with the idea to email my grandmother every Friday\u2026 [+3370 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Jorge Castillo",
#             "title": "Caballero's walk-off clinches playoff spot for Yanks",
#             "description": "Jos\u00e9 Caballero, acquired at the trade deadline to provide a versatile spark off the bench, swatted a two-out, walk-off single in the ninth inning Tuesday night against the White Sox to secure the Yankees their 60th postseason berth in franchise history.",
#             "url": "https://www.espn.com/mlb/story/_/id/46362654/yankees-clinch-playoff-spot-walk-win-close-blue-jays-al-east",
#             "urlToImage": "https://a3.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0924%2Fr1550242_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-24T05:20:10Z",
#             "content": "NEW YORK -- Jos\u00e9 Caballero, a Yankee for all of 54 days, proudly carried a championship belt -- given to the player of the game after every New York victory -- around his left shoulder as alcohol-soa\u2026 [+5947 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "CNET"
#             },
#             "author": "Gael Cooper",
#             "title": "Today's NYT Connections: Sports Edition Hints and Answers for Sept. 30, #372",
#             "description": "Here's today's Connections: Sports Edition answer and hints for groups. These clues will help you solve The New York Times' popular puzzle game, Connections: Sports Edition, every day.",
#             "url": "https://www.cnet.com/tech/gaming/todays-nyt-connections-sports-edition-hints-and-answers-for-sept-30-372/",
#             "urlToImage": "https://www.cnet.com/a/img/resize/b6a176556f33d8a7a6d33d6575c828a27a02cb83/hub/2024/10/16/c34cfc41-01f2-4b1a-80a8-f6479c50c02e/connections-sports-edition-6859.jpg?auto=webp&fit=crop&height=675&width=1200",
#             "publishedAt": "2025-09-29T20:30:03Z",
#             "content": "Looking for the most recent\u00a0regular Connections answers? Click here for today's Connections hints, as well as our daily answers and hints for The New York Times Mini Crossword, Wordle and Strands puz\u2026 [+1820 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Rolling Stone"
#             },
#             "author": "Tim Chan",
#             "title": "Mets vs. Marlins Livestream: How to Watch Today\u2019s Baseball Game Online Free",
#             "description": "There are also a few ways to watch the Mets vs. Marlins final regular season game online without cable, including ways to get a livestream for free.",
#             "url": "http://www.rollingstone.com/product-recommendations/streaming/mets-vs-marlins-livestream-watch-baseball-game-online-free-1235436994/",
#             "urlToImage": "https://www.rollingstone.com/wp-content/uploads/2025/09/GettyImages-2237500337.jpg?w=1024&h=683&crop=1",
#             "publishedAt": "2025-09-28T19:19:26Z",
#             "content": "If you purchase an independently reviewed product or service through a link on our website, Rolling Stone may receive an affiliate commission.\r\nIt\u2019s the final day of the MLB regular season, and just \u2026 [+2461 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Adventure.com"
#             },
#             "author": "Stacey Lastoe",
#             "title": "Chasing baseball games across the country showed me a new side to the US",
#             "description": "From the barbecue pits of Kansas City to the indie bookshops near minor-league parks, Stacey Lastoe was initially just tagging along to New York Mets baseball games with her husband. But somewhere between the dugout and the diner, baseball travel became her t\u2026",
#             "url": "https://adventure.com/baseball-travel-stadiums-usa-city-breaks/",
#             "urlToImage": "https://adventure.com/wp-content/uploads/2025/09/Baseball-travel-USA-NY-Mets-Citifield-tomas-eidsvold-vndHYmrMtaY-unsplash.jpg",
#             "publishedAt": "2025-10-01T14:00:00Z",
#             "content": "I bleed blue and orange now, but it wasnt always so. In fact, I never thought much about baseball until I started dating my now-husband, Steve. And I certainly wasnt planning vacations around Major L\u2026 [+820 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "M's seek fan who gave Raleigh's 60th ball to boy",
#             "description": "The Mariners are looking to connect with the man who gave a 12-year-old boy Cal Raleigh's 60th home run ball Wednesday night in Seattle.",
#             "url": "https://www.espn.com/mlb/story/_/id/46381753/mariners-look-fan-gave-raleigh-60th-hr-ball-boy",
#             "urlToImage": "https://a3.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0925%2Fr1551173_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-26T00:21:37Z",
#             "content": "Sep 25, 2025, 07:27 PM ET\r\nSEATTLE -- Cal Raleigh's 60th home run put the Mariners' All-Star catcher into one of the most exclusive clubs in baseball. It also made for a memorable moment in the outfi\u2026 [+2004 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Alden Gonzalez",
#             "title": "Surging Mariners secure one clinch, eye 'big one'",
#             "description": "A come-from-behind victory over the Rockies on Tuesday night sent the Mariners back into the postseason and placed them on the cusp of a long-awaited division title.",
#             "url": "https://www.espn.com/mlb/story/_/id/46363120/surging-mariners-clinch-playoff-berth-close-al-west-title",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0924%2Fr1550259_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-24T06:36:26Z",
#             "content": "SEATTLE -- In the end, when they needed a big hit, it was Josh Naylor, the man who brought such a noticeable energy to this surging Seattle Mariners team over these past two months, who delivered it.\u2026 [+4899 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Braves manager Snitker unsure about future",
#             "description": "Longtime Braves manager Brian Snitker is unsure about his future, saying he's been on the fence about retirement as the year comes to a close.",
#             "url": "https://www.espn.com/mlb/story/_/id/46410557/long-braves-manager-brian-snitker-unsure-future",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0909%2Fr1543254_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-28T18:35:36Z",
#             "content": "Sep 28, 2025, 02:17 PM ET\r\nATLANTA -- Atlanta Braves manager Brian Snitker is unsure about his future with the Braves.\r\nThe 69-year-old Snitker, whose contract expires after this year, has been subje\u2026 [+1944 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Cheezburger.com"
#             },
#             "author": "Elna McHilderson, Elna McHilderson",
#             "title": "\u2018No one talks that way about my momma\u2019: 11-year-old stands up to a Karen at the little league baseball game after she talks down to his mom who was standing up for him",
#             "description": "Parenting is a constant learning experience for everyone involved. Anything can be a life lesson, so you have to always been on your toes!! Pretty wild. Take this mom who had the most mixed emotions after finding out about a little petty revenge her 11-year-o\u2026",
#             "url": "https://cheezburger.com/42619397/no-one-talks-that-way-about-my-momma-11-year-old-stands-up-to-a-karen-at-the-little-league-baseball",
#             "urlToImage": "https://i.chzbgr.com/thumb1200/42619397/h0753205C/up-for-his-mom-after-a-karen-talks-about-her-behind-her-back-at-a-little-league-baseball-game",
#             "publishedAt": "2025-10-02T17:00:00Z",
#             "content": "Parenting is a constant learning experience for everyone involved. Anything can be a life lesson, so you have to always been on your toes!! Pretty wild. Take this mom who had the most mixed emotions \u2026 [+632 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "9to5Mac"
#             },
#             "author": "Chance Miller",
#             "title": "New iPad Pro leaks, Powerbeats Fit, notification summary UI oddities",
#             "description": "Benjamin and Chance talk about the week\u2019s Apple news, including the bonkers leak of the so-far-unannounced M5 iPad Pro, and then the FCC chipped in with showing off the new MacBook Pro and Vision Pro too. Also, Benjamin\u2019s robot vacuum got a dramatically bette\u2026",
#             "url": "https://9to5mac.com/2025/10/02/happy-hour-558/",
#             "urlToImage": "https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/02/9to5mac-happy-hour-lead1.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1",
#             "publishedAt": "2025-10-02T16:51:04Z",
#             "content": "Benjamin and Chance talk about the weeks Apple news, including the bonkers leak of the so-far-unannounced M5 iPad Pro, and then the FCC chipped in with showing off the new MacBook Pro and Vision Pro \u2026 [+861 chars]"
#         },
#         {
#             "source": {
#                 "id": "business-insider",
#                 "name": "Business Insider"
#             },
#             "author": "insider@insider.com (Chris Rosenberg)",
#             "title": "My 14-year-old picked up investing tips online. With a financial planner's help, he's now saving for his retirement.",
#             "description": "My teen saw an instagram reel about how saving now can set him up for a great retirement. A week later, he met with a financial planner.",
#             "url": "https://www.businessinsider.com/personal-finance/teen-investing-tips-online-met-with-financial-planner-retirement-2025-9",
#             "urlToImage": "https://i.insider.com/68d2cd8f183847aa39d74c33?width=1200&format=jpeg",
#             "publishedAt": "2025-09-24T22:09:02Z",
#             "content": "Even before he was old enough to get a traditional job, my son was making his own money. He launched businesses from a young age, such as reselling sneakers and flipping dirt bikes. He constantly tal\u2026 [+3988 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "9to5Mac"
#             },
#             "author": "Benjamin Mayo",
#             "title": "Report: Apple hoping to announce F1 streaming deal at upcoming US Grand Prix",
#             "description": "The long-gestating streaming rights deal between Apple and Formula 1 is apparently reaching the finish line. In his newsletter, Puck\u2019s John Ourand reports that the two sides have nearly finalized negotiations, with an eye to announce the partnership at the up\u2026",
#             "url": "https://9to5mac.com/2025/10/07/apple-f1-streaming-deal-austin-grand-prix/",
#             "urlToImage": "https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2025/07/tim-cook-formula-1.jpg-2.webp?resize=1200%2C628&quality=82&strip=all&ssl=1",
#             "publishedAt": "2025-10-07T18:10:59Z",
#             "content": "The long-gestating streaming rights deal between Apple and Formula 1 is apparently reaching the finish line. In his newsletter, Puck\u2019s John Ourand reports that the two sides have nearly finalized neg\u2026 [+1691 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Alden Gonzalez",
#             "title": "From The Big Dumper to ... the Etsy witch? Why Mariners might have the mojo to finally win it all",
#             "description": "Seattle has never won a World Series. Or even an American League pennant. Could a little bit of magic change that?",
#             "url": "https://www.espn.com/mlb/story/_/id/46365591/mlb-2025-playoffs-seattle-mariners-world-series-cal-raleigh-etsy-witch",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0925%2Fr1550979_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-26T11:20:40Z",
#             "content": "SEATTLE -- It had been 24 years and five days since this city experienced its last division title, a wait that turned its baseball fans into one of this country's most tortured. Babies were born, gre\u2026 [+19820 chars]"
#         },
#         {
#             "source": {
#                 "id": "business-insider",
#                 "name": "Business Insider"
#             },
#             "author": "Thibault Spirlet",
#             "title": "Jimmy Kimmel's suspension boosted his ratings to a 10-year high \u2014 history shows backlashes can make or break a host",
#             "description": "Jimmy Kimmel just joined a long list of hosts whose biggest ratings came with their most contentious moments \u2014 some survived, others didn't.",
#             "url": "https://www.businessinsider.com/kimmels-ratings-soar-post-suspension-lessons-from-late-night-blowups-2025-9",
#             "urlToImage": "https://i.insider.com/68d5356df9db348adc0c227a?width=1200&format=jpeg",
#             "publishedAt": "2025-09-26T09:27:10Z",
#             "content": "Jimmy Kimmel returned from suspension to his biggest audience in a decade, drawing 6.26 million viewers.Randy Holmes/Disney via Getty Images\r\n<ul><li>Jimmy Kimmel's suspension ended with a comeback e\u2026 [+6109 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Gizmodo.com"
#             },
#             "author": "Cheryl Eddy",
#             "title": "How Found Footage Helped Blumhouse Build Its Horror Empire",
#             "description": "An excerpt from 'Horror's New Wave: 15 Years of Blumhouse' digs into 'Sinister,' a key early success for the studio.",
#             "url": "https://gizmodo.com/how-found-footage-helped-blumhouse-build-its-horror-empire-2000663380",
#             "urlToImage": "https://gizmodo.com/app/uploads/2025/09/Sinister_still3-2-1200x675.jpg",
#             "publishedAt": "2025-09-30T20:45:06Z",
#             "content": "Blumhouse is celebrating its 15th anniversary this year, and today brings a new book that goes behind the scenes of the horror studio\u2018s meteoric and entertainingly gory rise.\r\nIts full title is Horro\u2026 [+11718 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Tigers topple Guardians in wild card, reach ALDS",
#             "description": "- Dillon Dingler homered in the sixth inning, Wenceel P\u00e9rez drove in a pair of runs in a four-run seventh and the Detroit Tigers defeated the Cleveland Guardians 6-3 Thursday to advance to the American League Division Series.",
#             "url": "https://www.espn.com/mlb/story/_/id/46469617/dillon-dingler-wenceel-perez-help-tigers-top-guardians-reach-alds",
#             "urlToImage": "https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1002%2Fr1554656_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-10-02T22:35:50Z",
#             "content": "CLEVELAND -- Dillon Dingler homered in the sixth inning, Wenceel P\u00e9rez drove in a pair of runs in a four-run seventh and the Detroit Tigers defeated the Cleveland Guardians6-3 Thursday to advance to \u2026 [+2345 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Guardians' Fry suffers facial fractures from HBP",
#             "description": "Cleveland Guardians designated hitter David Fry sustained a broken nose and facial fractures after he was hit in the face by a pitch from Detroit's Tarik Skubal in the sixth inning Tuesday.",
#             "url": "https://www.espn.com/mlb/story/_/id/46366835/guardians-david-fry-broken-nose-facial-fractures-hbp",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0924%2Fr1550173_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-24T16:50:13Z",
#             "content": "Sep 24, 2025, 12:27 PM ET\r\nCLEVELAND -- Guardians designated hitter David Fry sustained a broken nose and facial fractures after he was hit in the face by a pitch from Tarik Skubal in the sixth innin\u2026 [+3075 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Gizmodo.com"
#             },
#             "author": "Germain Lussier",
#             "title": "\u2018Afterlife with Archie\u2019 Will Rise From the Grave on Disney+",
#             "description": "The beloved Archie Comics zombie horror series will hit streaming thanks to the minds behind 'Riverdale.'",
#             "url": "https://gizmodo.com/afterlife-with-archie-will-rise-from-the-grave-on-disney-2000666209",
#             "urlToImage": "https://gizmodo.com/app/uploads/2025/10/Afterlife-With-Archie-1200x675.jpg",
#             "publishedAt": "2025-10-01T16:42:10Z",
#             "content": "The Archie gang has always had their issues, but now, they\u2019ll battle the undead on Disney+. The streamer has just given a script-to-series commitment to Afterlife With Archie, a one-hour drama series\u2026 [+1853 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": null,
#             "title": "Billionaire populist eyes power in Czech vote but may need help from extremes",
#             "description": "Andrej Babis has been taking notes from the US Maga movement but he may need to partner with ultra-nationalists.",
#             "url": "https://www.bbc.com/news/articles/cly1pr8298vo",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/abd5/live/dd9eca10-9ed1-11f0-bb60-7394d1f81bcb.jpg",
#             "publishedAt": "2025-10-02T03:09:54Z",
#             "content": "Rob CameronPrague Correspondent, Prague\r\nAndrej Babis has taken inspiration from the US Maga movement, not least his party's red caps saying \"Strong Czechia\"\r\nCzechs go to the polls on Friday and Sat\u2026 [+5301 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Forbes Membership, Forbes Staff, \n Forbes Membership, Forbes Staff\n https://www.forbes.com/sites/members-only-events/people/forbes-membership/",
#             "title": "Members-Only Event: Talking Baseball With Steve Forbes",
#             "description": "Join Steve October 27th at 12pm ET as he steps up to the plate in a live Q&A with Senior Editor Jabari Young for an in-depth look at the state and future of America's favorite pastime. You can also ask questions and cast your vote for who will win the World S\u2026",
#             "url": "https://www.forbes.com/sites/members-only-events/2025/09/26/members-only-event-talking-baseball-with-steve-forbes/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/68d6dc19febf6cd623ab33d6/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-09-26T19:59:30Z",
#             "content": "Talk fortune, foul balls and more MLB with Steve Forbes\r\nLast year's Yankees-Dodgers World Series was the most watched since 2017. Nearly 16 million people in the U.S. tuned in, including one fan in \u2026 [+2076 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Artofmanliness.com"
#             },
#             "author": "Brett & Kate McKay",
#             "title": "Odds & Ends: September 26, 2025",
#             "description": "Land\u2019s End Striped Rugby Shirt. While researching the rugby shirt guide we published earlier this week, I purchased one from Land\u2019s End. At around $50, it\u2019s reasonably priced and well-made. It\u2019s 100% cotton that\u2019s been garment-washed so it feels broken in, no\u2026",
#             "url": "https://www.artofmanliness.com/odds-ends/odds-ends-september-26-2025/",
#             "urlToImage": "https://content.artofmanliness.com/uploads/2023/01/Odds-and-Ends-no-logo-header-1.jpg",
#             "publishedAt": "2025-09-26T12:40:47Z",
#             "content": "Land\u2019s End Striped Rugby Shirt. While researching the rugby shirt guide we published earlier this week, I purchased one from Land\u2019s End. At around $50, it\u2019s reasonably priced and well-made. It\u2019s 100%\u2026 [+3355 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Dan Schlossberg, Senior Contributor, \n Dan Schlossberg, Senior Contributor\n https://www.forbes.com/sites/danschlossberg/",
#             "title": "Costly Free Agents Help Yankees And Dodgers Reach Playoffs Again",
#             "description": "On the final day of the 2025 baseball season, three undecided races were settled and two major collapses concluded.",
#             "url": "https://www.forbes.com/sites/danschlossberg/2025/09/28/costly-free-agents-help-yankees-and-dodgers-reach-playoffs-again/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/68d9bc584653de80a996f9b7/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-09-28T23:04:24Z",
#             "content": "Lured by the largest and longest contract in baseball history, Juan Soto jumped from the Mets to the Yankees and hit a career-best 43 homers. (Photo by Jim McIsaac/Getty Images)\r\nGetty Images\r\nFollow\u2026 [+7571 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "NPR"
#             },
#             "author": "Brittney Melton",
#             "title": "Government shutdown odds increase. And, Trump shifts stance on Russia-Ukraine war",
#             "description": "President Trump canceled a meeting Democrats, increasing the odds of a potential government shutdown. And, the president suggests that Ukraine could win back all the territory it lost to Russia.",
#             "url": "https://www.npr.org/2025/09/24/g-s1-90292/up-first-newsletter-government-shutdown-unga-russia-ukraine-jimmy-kimmel-returns",
#             "urlToImage": "https://npr.brightspotcdn.com/dims3/default/strip/false/crop/6000x3375+0+313/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F9e%2F52%2Fd89c4386451d90b5a0772984772b%2Fgettyimages-2236981683.jpg",
#             "publishedAt": "2025-09-24T11:06:27Z",
#             "content": "Good morning. You're reading the Up First newsletter.\u00a0Subscribe\u00a0here to get it delivered to your inbox, and\u00a0listen\u00a0to the Up First podcast for all the news you need to start your day.\r\nToday's top st\u2026 [+6218 chars]"
#         },
#         {
#             "source": {
#                 "id": "business-insider",
#                 "name": "Business Insider"
#             },
#             "author": "Alice Tecotzky",
#             "title": "I expected the Ryder Cup to be one big frat party. The level of corporate polish caught me by surprise.",
# ...
#             "description": "The Red Sox are in offseason mode after being bounced by the Yankees last week. Chief baseball officer Craig Breslow met with reporters on Monday to discuss the upcoming winter (links via Tim Healey of The Boston Globe and Jen McCaffrey of The Athletic). Like\u2026",
#             "url": "https://www.mlbtraderumors.com/2025/10/craig-breslow-discusses-red-soxs-offseason-plans.html",
#             "urlToImage": "https://cdn.mlbtraderumors.com/files/2025/10/USATSI_25998635-1024x683.jpg",
#             "publishedAt": "2025-10-08T04:08:36Z",
#             "content": "The Red Sox are in offseason mode after being bounced by the Yankees last week. Chief baseball officer Craig Breslow met with reporters on Monday to discuss the upcoming winter (links via Tim Healey \u2026 [+6506 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Rob Demovsky",
#             "title": "Micah Parsons' hobby? Beating Packers teammates at HORSE, pingpong and bowling",
#             "description": "\"We just building relationships,\" Parsons said of competing with his new teammates ahead of Sunday's return to Dallas.",
#             "url": "https://www.espn.com/nfl/story/_/id/46376547/nfl-green-bay-packers-micah-parsons-dallas-cowboys",
#             "urlToImage": "https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0925%2Fr1550940_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-26T11:20:40Z",
#             "content": "GREEN BAY, Wis. -- When Micah Parsons first toured the Green Bay Packers' headquarters inside Lambeau Field, his eyes lit up when he noticed something hanging from the walls near the weight room, ind\u2026 [+5928 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Matt Bowen",
#             "title": "Last-minute pickups for Week 4: Elic Ayomanor, Chargers D/ST among top options",
#             "description": "Do injuries have you seeking a late-week pickup? Need a defense to stream? We have options with favorable setups.",
#             "url": "https://www.espn.com/fantasy/football/story/_/id/46365535/fantasy-football-streaming-last-minute-pickups-week-4-free-agents",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0922%2Fr1549433_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-26T11:20:40Z",
#             "content": "At various points during the fantasy football season, injuries, bye weeks and breaking news can cause you to need reinforcements for your fantasy lineup. Every Friday throughout the 2025 NFL season, \u2026 [+5883 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Matt Bowen",
#             "title": "Trade DK? Go get Skattebo? Three players you should trade, three to acquire",
#             "description": "Three players you should target in a trade and three you can ship away while their value is up, including DK Metcalf.",
#             "url": "https://www.espn.com/fantasy/football/story/_/id/46449288/fantasy-football-week-5-pickups-trade-candidates",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1001%2Fr1553948_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-10-02T12:05:02Z",
#             "content": "Slow start to your fantasy season? It might be the right time to make a trade to get back into it. And the same goes for managers at the top of the standings, because there are multiple sell-high can\u2026 [+6637 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "MLB Trade Rumors"
#             },
#             "author": "Steve Adams",
#             "title": "Offseason Outlook: St. Louis Cardinals",
#             "description": "The Cardinals officially have a new head of baseball operations for the first time in nearly two decades. As announced at the beginning of last offseason, longtime president of baseball ops John Mozeliak has stepped aside and passed the torch to former Rays a\u2026",
#             "url": "https://www.mlbtraderumors.com/2025/10/offseason-outlook-st-louis-cardinals-15.html",
#             "urlToImage": "https://cdn.mlbtraderumors.com/files/2022/08/USATSI_18944530-1024x683.jpg",
#             "publishedAt": "2025-10-08T01:18:23Z",
#             "content": "The Cardinals officially have a new head of baseball operations for the first time in nearly two decades. As announced at the beginning of last offseason, longtime president of baseball ops John Moze\u2026 [+2431 chars]"
#         },
#         {
#             "source": {
#                 "id": "fox-sports",
#                 "name": "Fox Sports"
#             },
#             "author": "Fox Sports",
#             "title": "Brewers are out to PROVE a point after 2-0 lead vs Cubs  Derek Jeter, Big Papi & A-Rod weigh in",
#             "description": "Derek Jeter, David Ortiz and Alex Rodriguez reveal why the Milwaukee Brewers are the most balanced team in baseball after leading the Chicago Cubs, 2-0.",
#             "url": "https://www.foxsports.com/watch/fmc-zr4i5b9lmo03gxqv",
#             "urlToImage": "https://a57.foxsports.com/static-media.fox.com/fmc/prod/sports/VX-14311041/1280/720/0hn3tt1mwezvxzap.jpg?ve=1&tl=1",
#             "publishedAt": "2025-10-07T21:36:52Z",
#             "content": ""
#         },
#         {
#             "source": {
#                 "id": "fox-sports",
#                 "name": "Fox Sports"
#             },
#             "author": null,
#             "title": "FOX Sports to Air 2026 World Baseball Classic, Including March 17 Championship",
#             "description": "FOX Sports will be the exclusive home for all 47 games of the 2026 World Baseball Classic, including the Championship Game on March 17.",
#             "url": "https://www.foxsports.com/stories/mlb/fox-broadcasts-2026-world-baseball-classic-games-schedule",
#             "urlToImage": "https://a57.foxsports.com/statics.foxsports.com/www.foxsports.com/content/uploads/2025/10/1408/814/wbcmain.jpg?ve=1&tl=1",
#             "publishedAt": "2025-10-07T19:12:18Z",
#             "content": "We all remember the epic conclusion to the 2023 World Baseball Classic. Japan and the United States locked in an instant classic with the title on the line. Shohei Ohtani stared down fellow MLB super\u2026 [+2333 chars]"
#         },
#         {
#             "source": {
#                 "id": "fox-sports",
#                 "name": "Fox Sports"
#             },
#             "author": null,
#             "title": "Best MLB Betting Sites & Promos 2025: Top Sportsbooks and Bonuses",
#             "description": "Discover the best MLB betting sites in 2025. Compare trusted sportsbooks, welcome bonuses, live betting options, and futures odds for baseball fans.",
#             "url": "https://www.foxsports.com/stories/betting/best-mlb-betting-sites-promos-2025-top-sportsbooks-bonuses",
#             "urlToImage": "https://a57.foxsports.com/statics.foxsports.com/www.foxsports.com/content/uploads/2025/09/1408/814/shohei_ohtani_horizontal.jpg?ve=1&tl=1",
#             "publishedAt": "2025-09-24T03:29:10Z",
#             "content": "This page may contain affiliate links to legal sports betting partners. If you sign up or place a wager, FOX Sports may be compensated. Read more about Sports Betting on FOX Sports\r\n.\r\nWagering on ML\u2026 [+23273 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "MLB games up 2 minutes in pitch clock's 3rd year",
#             "description": "The average time of a nine-inning major league baseball game increased by 2 minutes this season to 2:38 in the third year of the pitch clock.",
#             "url": "https://www.espn.com/mlb/story/_/id/46422703/average-mlb-game-2-minutes-3rd-year-pitch-clock",
#             "urlToImage": "https://a3.espncdn.com/combiner/i?img=%2Fphoto%2F2024%2F1001%2Fr1394597_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-29T17:20:44Z",
#             "content": "Sep 29, 2025, 01:12 PM ET\r\nNEW YORK -- The average time of a nine-inning major league baseball game increased by 2 minutes this season to 2:38 in the third year of the pitch clock.\r\nMLB's average fel\u2026 [+437 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Wayne G. McDonnell, Jr., Contributor, \n Wayne G. McDonnell, Jr., Contributor\n https://www.forbes.com/sites/waynemcdonnell/",
#             "title": "Why Aaron Judge Defines Valuable Through Years Of Elite Consistency",
#             "description": "Aaron Judge has been the personification of elite consistency as he battles Cal Raleigh for the 2025 American League Most Valuable Player Award.",
#             "url": "https://www.forbes.com/sites/waynemcdonnell/2025/09/28/why-aaron-judge-defines-valuable-through-years-of-elite-consistency/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/68d94174bdc10074f073463e/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-09-28T16:47:03Z",
#             "content": "NEW YORK, NEW YORK - SEPTEMBER 27: Aaron Judge #99 of the New York Yankees runs after hitting a 2-run RBI double during the fifth inning against the Baltimore Orioles at Yankee Stadium on September 2\u2026 [+6878 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Phillies star Harper OK with boos: 'I love our fans'",
#             "description": "Bryce Harper said he doesn't mind the boos from an angry Phillies fanbase, calling them some of the best fans in baseball and a crowd he enjoys.",
#             "url": "https://www.espn.com/mlb/story/_/id/46525424/love-our-fans",
#             "urlToImage": "https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1008%2Fr1557194_1024x576_16%2D9.jpg",
#             "publishedAt": "2025-10-08T01:22:06Z",
#             "content": "LOS ANGELES -- The loud booing by angry Philadelphia Phillies fans at their home ballpark likely drowned out similar noise Bryce Harper was making.\r\nThe Phillies slugger has a single and three strike\u2026 [+2003 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Fangraphs.com"
#             },
#             "author": "David Appelman",
#             "title": "Job Posting: Cleveland Guardians \u2013 Baseball Technology Fellow",
#             "description": "The Cleveland Guardians are hiring.",
#             "url": "https://blogs.fangraphs.com/instagraphs/job-posting-cleveland-guardians-baseball-technology-fellow-4/",
#             "urlToImage": "https://blogs.fangraphs.com/wp-content/uploads/2022/02/Job-Posting-Board-.png",
#             "publishedAt": "2025-10-03T12:20:22Z",
#             "content": "Baseball Technology Fellow\r\nPrimary PurposeThe Cleveland Guardians Fellowship program is designed to accelerate the pace of development and impact for people interested in working for our organizatio\u2026 [+5775 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": null,
#             "title": "Bloom takes over Cards, says Marmol to return",
#             "description": "Chaim Bloom says the Cardinals will be sticking to their roots to get back to October baseball and that manager Oli Marmol will return.",
#             "url": "https://www.espn.com/mlb/story/_/id/46437663/chaim-bloom-takes-cardinals-says-oli-marmol-return",
#             "urlToImage": "https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2024%2F0930%2Fr1394313_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-09-30T18:37:31Z",
#             "content": "Sep 30, 2025, 02:20 PM ET\r\nST. LOUIS -- Chaim Bloom says the St. Louis Cardinals will be sticking to their roots to get back to October baseball.\r\nBloom, who has been in line since last year to becom\u2026 [+2751 chars]"
#         },
#         {
#             "source": {
#                 "id": "espn",
#                 "name": "ESPN"
#             },
#             "author": "Jenna Laine",
#             "title": "Was Buccaneers WR Egbuka destined for MLB? His childhood dreams blossomed at the Mariners' stadium",
#             "description": "Bucs rookie sensation Emeka Egbuka could have been a baseball star, but COVID closed the doors during his high school years.",
#             "url": "https://www.espn.com/nfl/story/_/id/46476791/tampa-bay-buccaneers-emeka-egbuka-baseball-star-mlb-seattle-mariners",
#             "urlToImage": "https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1003%2Fr1555002_1296x729_16%2D9.jpg",
#             "publishedAt": "2025-10-04T11:35:11Z",
#             "content": "TAMPA, Fla. -- In the alternate universe proposed to Tampa Bay Buccaneers wide receiver Emeka Egbuka in a question asked by ESPN on Wednesday, the wideout isn't catching passes from Baker Mayfield or\u2026 [+11443 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "MLB Trade Rumors"
#             },
#             "author": "Darragh McDonald",
#             "title": "Nationals Finalizing Deal With Paul Toboni As New Head Of Baseball Operations",
#             "description": "The Nationals are finalizing a deal with Paul Toboni as the new head of their baseball operations department, reports Jeff Passan of ESPN. More to come.",
#             "url": "https://www.mlbtraderumors.com/2025/09/nationals-finalizing-deal-with-paul-toboni-as-new-head-of-baseball-operations.html",
#             "urlToImage": "https://cdn.mlbtraderumors.com/files/2023/06/USATSI_20354662-1024x683.jpg",
#             "publishedAt": "2025-09-24T18:18:24Z",
#             "content": "The Nationals are finalizing a deal with Paul Toboni as the new head of their baseball operations department, reports Jeff Passan of ESPN. It\u2019s unclear what Toboni\u2019s official title will be or when th\u2026 [+123 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Cracked.com"
#             },
#             "author": "JM McNab",
#             "title": "Red Sox Fans Discover a New Reason to Be Mad at Jimmy Fallon",
#             "description": "By\n JM McNab\n Published: October 03rd, 2025",
#             "url": "https://www.cracked.com/article_48624_red-sox-fans-discover-a-new-reason-to-be-mad-at-jimmy-fallon.html",
#             "urlToImage": "https://s3.crackedcdn.com/phpimages/article/1/7/9/1376179.jpg",
#             "publishedAt": "2025-10-03T17:30:00Z",
#             "content": "The past week has given the world a number of reasons to be annoyed at\u00a0Tonight Show\u00a0host/overpriced pajama pitchman Jimmy Fallon.\r\nFor starters, Fallon promised to respond to recent threats of White \u2026 [+2353 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Cracked.com"
#             },
#             "author": "JM McNab",
#             "title": "John Candy Came Shockingly Close to Starring in \u2018Goodfellas\u2019",
#             "description": "By\n JM McNab\n Published: October 02nd, 2025",
#             "url": "https://www.cracked.com/article_48604_john-candy-came-shockingly-close-to-starring-in-goodfellas.html",
#             "urlToImage": "https://s3.crackedcdn.com/phpimages/article/4/7/5/1375475.jpg",
#             "publishedAt": "2025-10-02T16:30:00Z",
#             "content": "More than 30 years after his tragic death, John Candy remains one of the most beloved movie stars of all-time, having appeared in comedy classics like\u00a0Planes, Trains and Automobiles,\u00a0Spaceballs,\u00a0Home\u2026 [+2418 chars]"
#         }
#     ]
# }

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 5. Extracting authors, sources, and descriptions from articles

# %%
import time

authors = [ article['author'] for article in all_articles['articles'] ]

sources = [ article['source']['name'] for article in all_articles['articles'] ]

descriptions = [ article['description'] for article in all_articles['articles'] ]

print(type(descriptions))
# Compute a collection of all words from all tweets
words = [
    w
    for d in descriptions
    if d is not None          # skip None values
    for w in d.split()
]

# Explore the first 5 items for each...

print(json.dumps(authors[0:5], indent=1))
print(json.dumps(sources[0:5], indent=1))
print(json.dumps(descriptions[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# <class 'list'>
# [
#  "Mike Sorrentino",
#  "Eric Karabell",
#  "David Schoenfield",
#  "Becky Sullivan",
#  "Joe Rossignol"
# ]
# [
#  "CNET",
#  "ESPN",
#  "ESPN",
#  "NPR",
#  "MacRumors"
# ]
# [
#  "Apple's new Pro phone will be used to film the Detroit Tigers vs. Boston Red Sox MLB game Friday night.",
#  "The 2025 fantasy baseball season just ended, but Eric Karabell is already thinking about 2026.",
#  "There's still a lot at stake entering the final weekend of the regular season. We have your guide to the last few days of baseball before October.",
#  "Twelve teams will enter October, but only one team will leave (with a ring). You can root for the three franchises that have never won a title before \u2026 or you can pull for the Yankees or Dodgers.",
#  "Apple TV+'s broadcast of the Boston Red Sox vs. Detroit Tigers game at Fenway Park tonight will incorporate live footage captured with the iPhone 17 Pro.\n\n\n\nImage Credit: Apple TV+\n\nApple says the iPhone 17 Pro will capture live gameplay, along with batting p\u2026"
# ]
# [
#  "Apple's",
#  "new",
#  "Pro",
#  "phone",
#  "will"
# ]

# %% [markdown]
# # Back to the slides

# %% [markdown]
# # Example 6. Creating a basic frequency distribution from the words in articles

# %%
from collections import Counter

for item in [authors, sources, words]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [(None, 16), ('Eric Karabell', 4), ('info@hypebeast.com (Hypebeast)', 4), ('Gael Cooper', 3), ('Alden Gonzalez', 3), ('ABC News', 3), ('ESPN Fantasy', 3), ('Benjamin Mayo', 2), ('Jake Rossen', 2), ('J.J. Post', 2)]
# [('ESPN', 30), ('Business Insider', 6), ('Forbes', 6), ('Fox Sports', 6), ('CNET', 5), ('MLB Trade Rumors', 5), ('NPR', 4), ('HYPEBEAST', 4), ('9to5Mac', 3), ('Gizmodo.com', 3)]
# [('the', 159), ('a', 75), ('of', 69), ('to', 58), ('and', 56), ('for', 38), ('in', 37), ('baseball', 32), ('The', 24), ('with', 24)]

# %% [markdown]
# # Example 7. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words),
                    ('Author', authors),
                    ('Source', sources)):
    pt = PrettyTable(field_names=[label, 'Count'])
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 from prettytable import PrettyTable
#       3 for label, data in (('Word', words),
#       4                     ('Author', authors),
#       5                     ('Source', sources)):
#       6     pt = PrettyTable(field_names=[label, 'Count'])
#
# ModuleNotFoundError: No module named 'prettytable'

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 8. Calculating lexical diversity for articles

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens)

# A function for computing the average number of words per tweet
def average_words(statuses):
    valid_statuses = [s for s in statuses if isinstance(s, str) and s.strip()]

    if not valid_statuses:
        return 0.0  # or handle however you prefer (e.g. return None)

    total_words = sum(len(s.split()) for s in valid_statuses)
    return total_words / len(valid_statuses)

print(lexical_diversity(words))
print(average_words(descriptions))
# Out:
# 0.5157522123893805
# 28.535353535353536

# %% [markdown]
# ## Back to slides

# %% [markdown]
# #  Example 9. Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
plt.show()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 639, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1985, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/m9/cwh1x1690_jdw4s6x8h_csfr0000gq/T/ipykernel_62720/3184200949.py", line 1, in <module>
#     import matplotlib
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py", line 159, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/rcsetup.py", line 28, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/colors.py", line 57, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/ticker.py", line 144, in <module>
#     from matplotlib import transforms as mtransforms
#   File "/opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import matplotlib
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:159
#     155 from packaging.version import parse as parse_version
#     157 # cbook must import matplotlib only within function
#     158 # definitions, so it is safe to import from it here.
# --> 159 from . import _api, _version, cbook, _docstring, rcsetup
#     160 from matplotlib.cbook import sanitize_sequence
#     161 from matplotlib._api import MatplotlibDeprecationWarning
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/rcsetup.py:28
#      26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
# ---> 28 from matplotlib.colors import Colormap, is_color_like
#      29 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      30 from matplotlib._enums import JoinStyle, CapStyle
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/colors.py:57
#      55 import matplotlib as mpl
#      56 import numpy as np
# ---> 57 from matplotlib import _api, _cm, cbook, scale
#      58 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      61 class _ColorMapping(dict):
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/ticker.py:144
#     142 import matplotlib as mpl
#     143 from matplotlib import _api, cbook
# --> 144 from matplotlib import transforms as mtransforms
#     146 _log = logging.getLogger(__name__)
#     148 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     149            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     150            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     156            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     157            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: initialization failed

# %% [markdown]
# # Back to the slides

# %% [markdown]
# # Example 10. Image segmentation using Hugging Face

# %%
# !pip install -q datasets transformers evaluate timm albumentations

# %%
from IPython.display import Image
image_urls = {}

for i in range(5):
  print(i)
  print(all_articles['articles'][i]['title'])
  try:
    image_url = all_articles['articles'][i]['urlToImage']
    article = all_articles['articles'][i]
    image = Image(url=image_url)
    display(image)
    image_urls[i] = image_url
  except ValueError:
    print('no image')

# %%
# Pick an image
image_url = image_urls[3]

# %%
from transformers import pipeline
import requests
from PIL import Image, ImageDraw

# %%
image = Image.open(requests.get(image_url, stream=True).raw)

# %%
#obj_detector = pipeline(task="object-detection")
obj_detector = pipeline(
    task="object-detection",
    model="facebook/detr-resnet-50"  # explicitly specify model
)
#https://huggingface.co/facebook/detr-resnet-50
#COCO2017 dataset contains 80 object categories
#https://tech.amikelive.com/node-718/what-object-categories-labels-are-in-coco-dataset/

# %%
results = obj_detector(image)

# %%
draw = ImageDraw.Draw(image)

for result in results:
    score, label, box = result["score"], result["label"], result["box"]
    x, y, x2, y2 = box['xmin'], box['ymin'], box['xmax'], box['ymax'],
    draw.rectangle((x, y, x2, y2), outline="red", width=1)
    draw.text((x, y), label, fill="white")

image
